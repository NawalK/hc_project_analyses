# %%
import sys,json

sys.path.append('/cerebro/cerebro1/dataset/bmpd/derivatives/HealthyControls_project/hc_project_analyses/code/')

from plotting_CL import Plotting
from compute_similarity import compute_similarity

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Load configuration file

# %%
with open('../config/config_spine_only_CL.json') as config_file:
    config = json.load(config_file)

# %%
'/cerebro/cerebro1/dataset/bmpd/derivatives/HealthyControls_project/' + config['data']['mtl']['ica']['spinalcord']['dir']
# Out:
# '/cerebro/cerebro1/dataset/bmpd/derivatives/HealthyControls_project//ICA/mtl/spinalcord/'

# %%
params_qual_1 = {'k':10, 'dataset':'mtl', 'analysis':'ica'}
#params_qual_2 = {'k':10, 'dataset':'mtl', 'analysis':'icap'}
plotting = Plotting(config,'spinalcord',params1=params_qual_1,params2=None)

# %%
plotting.sc_plot(show_spinal_levels=True, k_per_line=9, lthresh=1, uthresh=5, save_results=False)

# %% [markdown]
# ## Spinal cord plotting

# %%
plotting.sc_plot(show_spinal_levels=True,k_per_line=10,lthresh=3,uthresh=6,colormap='turbo',perc_thresh=None,save_results=False)

# %% [markdown]
# ## Brain plotting

# %%
plotting.brain_plot(k_per_line=2, lthresh=2.3, uthresh=4.0, centering_method='max', colormap='autumn', direction='xyz', save_results=False)
