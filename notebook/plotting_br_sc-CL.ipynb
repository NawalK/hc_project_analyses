# %%
import sys,json

sys.path.append('/cerebro/cerebro1/dataset/bmpd/derivatives/HealthyControls_project/hc_project_analyses/code/')

from plotting import Plotting
from compute_similarity import compute_similarity

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# /cerebro/cerebro1/dataset/bmpd/derivatives/thibault_test/code/toolbox/bmpd_python/lib/python3.6/site-packages/nilearn/__init__.py:69: FutureWarning: Python 3.6 support is deprecated and will be removed in release 0.10 of Nilearn. Consider switching to Python 3.8 or 3.9.
#   _python_deprecation_warnings()

# %% [markdown]
# ## Load configuration file

# %%
with open('../config/config_spine_only_CL.json') as config_file:
    config = json.load(config_file)

# %%
params_qual_1 = {'k':15, 'dataset':'gva', 'analysis':'ica'}
params_qual_2 = {'k':30, 'dataset':'mtl', 'analysis':'ica'}
plotting = Plotting(config,'spinalcord',params1=params_qual_1,params2=params_qual_2)

# %%
plotting.sc_plot(show_spinal_levels=True, k_per_line=9, lthresh=1.3, uthresh=5, save_results=False)
# Out:
# COMPUTING SIMILARITY WITH METHOD: Dice
# ...Compute similarity between pairs of components
# ...Ordering components based on maximum weight matching
# DONE!

# %%
plotting.sc_plot(show_spinal_levels=True, k_per_line=9, lthresh=1.6, uthresh=5, save_results=False)
# Out:
# COMPUTING SIMILARITY WITH METHOD: Dice
# ...Compute similarity between pairs of components
# ...Ordering components based on maximum weight matching
# DONE!

# %% [markdown]
# ## Spinal cord plotting

# %%
plotting.sc_plot(show_spinal_levels=True,k_per_line=10,lthresh=3,uthresh=6,colormap='turbo',perc_thresh=None,save_results=False)

# %% [markdown]
# ## Brain plotting

# %%
plotting.brain_plot(k_per_line=2, lthresh=2.3, uthresh=4.0, centering_method='max', colormap='autumn', direction='xyz', save_results=False)
