# %%
import sys,json

sys.path.append('/media/miplab-nas2/Data3/BMPD/hc_project/analysis/code/')

from plotting import Plotting
from compute_similarity import compute_similarity

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# /home/kinany/.local/lib/python3.9/site-packages/nilearn/input_data/__init__.py:27: FutureWarning: The import path 'nilearn.input_data' is deprecated in version 0.9. Importing from 'nilearn.input_data' will be possible at least until release 0.13.0. Please import from 'nilearn.maskers' instead.
#   warnings.warn(message, FutureWarning)

# %% [markdown]
# ## Load configuration file

# %%
with open('../config/config_NK.json') as config_file:
    config = json.load(config_file)

# %%
plotting = Plotting(config,20,['iCAP']) # "'ICA'" or "iCAP" or ['ICA','iCAP']
# Out:
# ['iCAP']
# /media/miplab-nas2/Data3/BMPD/hc_project/data/icap/spinalcord//K_20/comp_zscored/iCAPs_z.nii

# %%
plotting.map_order
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 plotting.map_order
#
# NameError: name 'plotting' is not defined

# %% [markdown]
# ## Spinal cord plotting

# %%
plotting.sc_plot(show_spinal_levels=True,k_per_line=10,lthresh=3,uthresh=6,colormap='turbo',perc_thresh=None,save_results=False)

# %% [markdown]
# ## Brain plotting

# %%
plotting.brain_plot(k_per_line=2, lthresh=2.3, uthresh=4.0, centering_method='max', colormap='autumn', direction='xyz', save_results=False)
