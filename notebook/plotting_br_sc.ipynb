# %%
import sys,json

sys.path.append("/cerebro/cerebro1/dataset/bmpd/derivatives/HealthyControls_project/hc_project_analyses/code/")

from plotting import Plotting
from compute_similarity import compute_similarity

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# /cerebro/cerebro1/dataset/bmpd/derivatives/thibault_test/code/toolbox/bmpd_python/lib/python3.6/site-packages/nilearn/__init__.py:69: FutureWarning: Python 3.6 support is deprecated and will be removed in release 0.10 of Nilearn. Consider switching to Python 3.8 or 3.9.
#   _python_deprecation_warnings()
# /cerebro/cerebro1/dataset/bmpd/derivatives/thibault_test/code/toolbox/bmpd_python/lib/python3.6/site-packages/nilearn/input_data/__init__.py:27: FutureWarning: The import path 'nilearn.input_data' is deprecated in version 0.9. Importing from 'nilearn.input_data' will be possible at least until release 0.13.0. Please import from 'nilearn.maskers' instead.
#   warnings.warn(message, FutureWarning)

# %% [markdown]
# ## Load configuration file

# %%
#config_BMPD_HC_CL.json #config_SPiCiCAP_CL.json
with open('../config/config_BMPD_HC_CL.json') as config_file:
    config = json.load(config_file)

# %%
plotting = Plotting(config,10,['ica']) # "'ICA'" or "iCAP" or ['ICA','iCAP']
plotting.sc_plot(show_spinal_levels=True,k_per_line=5,lthresh=2,perc_thresh=None,save_results=False)#20
# Out:
# ['ica']
# /cerebro/cerebro1/dataset/bmpd/derivatives/HealthyControls_project//ICA/BMPD_HC/spinalcord//K_10/comp_zscored/zCanICA_21sbj_spinalcord_spinalcord_4D_K_10.nii.gz

# %%
plotting = Plotting(config,40,['ICA']) # "'ICA'" or "iCAP" or ['ICA','iCAP']
# Out:
# ['ICA']
# /cerebro/cerebro1/dataset/bmpd/derivatives/HealthyControls_project//ICA/SPiCiCAP/spinalcord//K_40/comp_zscored/zCanICA_19sbj_spinalcord_spinalcord_4D_K_40.nii.gz

# %%
plotting.sc_plot(show_spinal_levels=True,k_per_line=10,lthresh=4,uthresh=7.0,perc_thresh=None,save_results=False)#20

# %%
plotting.sc_plot(show_spinal_levels=True,k_per_line=9,lthresh=1.6,perc_thresh=None,save_results=False)#20

# %% [markdown]
# ## Spinal cord plotting

# %%
plotting.sc_plot(show_spinal_levels=True,k_per_line=9,lthresh=1.6,perc_thresh=None,save_results=False)#20

# %%
plotting.sc_plot(show_spinal_levels=True,k_per_line=9,lthresh=1.6,perc_thresh=None,save_results=False)#30

# %%
plotting.sc_plot(show_spinal_levels=True,k_per_line=9,lthresh=1.6,perc_thresh=None,save_results=False) #n=50

# %%
plotting = Plotting(config,9,['iCAP']) # "'ICA'" or "iCAP" orc
plotting.sc_plot(show_spinal_levels=True,k_per_line=9,lthresh=2,perc_thresh=None,save_results=False)
# Out:
# ['iCAP']
# /cerebro/cerebro1/dataset/bmpd/derivatives/HealthyControls_project//iCAP/spinalcord//K_9/comp_zscored/iCAPs_z4D.nii

# %%
config['main_dir']+config['data']['iCAP']['spinalcord_dir'] + '/K_' + str(9) + '/comp_zscored/*' + config['data']['iCAP']["tag_filename"]
# Out:
# '/cerebro/cerebro1/dataset/bmpd/derivatives/HealthyControls_project//iCAP/spinalcord//K_9/comp_zscored/*4D'

# %% [markdown]
# ## Brain plotting

# %%
plotting.brain_plot(k_per_line=2, lthresh=2.3, uthresh=4.0, centering_method='max', colormap='autumn', direction='xyz', save_results=False)
