# %%
import sys,json

sys.path.append("/cerebro/cerebro1/dataset/bmpd/derivatives/HealthyControls_project/hc_project_analyses/code/")

from plotting import Plotting
from compute_similarity import compute_similarity

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Load configuration file

# %%
with open('../config/config_CL.json') as config_file:
    config = json.load(config_file)

# %%
plotting = Plotting(config,10,['ICA']) # "'ICA'" or "iCAP" or ['ICA','iCAP']
# Out:
# ['ICA']

# %% [markdown]
# ## Spinal cord plotting

# %%
plotting.sc_plot(show_spinal_levels=True,k_per_line=10,lthresh=3,save_results=False)

# %% [markdown]
# ## Brain plotting

# %%
plotting.brain_plot(k_per_line=2, lthresh=2.3, uthresh=4.0, centering_method='max', colormap='autumn', direction='xyz', save_results=False)
