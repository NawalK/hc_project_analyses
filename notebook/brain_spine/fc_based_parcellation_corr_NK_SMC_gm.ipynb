# %% [markdown]
# # <font color=black> Analysis - FC-based parcellation using correlation </font>
# <hr style="border:1px solid black">

# %%
import sys,json
import glob, os
import numpy as np
import nibabel as nib
import time
from nilearn import datasets, plotting, image, surface
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap

sys.path.append('/media/miplab-nas2/Data3/BMPD/hc_project/analysis/code/')

from fc_based_parcellation import FC_Parcellation

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Initialization
# <hr style="border:0.5px solid black">

# %% [markdown]
# ### Load existing configuration file ...

# %%
# Load the config file with all information
filetag = "iCAP_SMC_to_C1toC7_gm"
with open('../../../brain_spine/results/fc_parcellation/corr/' + filetag + '/config_' + filetag + '.json') as config_file:
    config = json.load(config_file)
target = 'spinalcord'
source = 'brain'
config['brain_surfaces']='/templates/surf/'
# Instantiate class
# Note: this will save a config file with all relevant information and prepare folder structure
fc_parcellation = FC_Parcellation(config,source,target,'corr')

# %% [markdown]
# ### ... or build new one

# %%
# Load the config file with all information
with open('../../config/config_fc_based_parcellation_NK.json') as config_file:
    config = json.load(config_file)
# Define tag of this analysis (used for saving)
config['output_tag'] = "C1toC7_gm_07_notsmoothed_to_wholebrain"
# Define source, target, and the corresponding masks
source = 'spinalcord'
target = 'brain'
# Note: paths should be with respect to main directory
config['file_tag']['spinalcord'] = "_task-rest_bold_stc_sc_moco_brsc_BP_inTemplate.nii.gz"
config['file_tag']['brain'] = "_task-rest_bold_stc_brain_moco_brsc_BP_reg_SPM_inTemplate3mm_s.nii.gz"

config['masks']['source'] = "/templates/PAM50_hc_project/template/PAM50_gm_bin07_C1C7.nii.gz"
config['masks']['target'] = "/analysis/masks/brain_old_3mm/MNI_GM_3mm.nii.gz"

config['brain_surfaces']='/templates/surf/'

config['list_subjects'] = ["P030", "P099","A006","A007","A008","A009","A011","A013","A023","A024","A025","A026","A027","A028","A029","A030","A032","A033","A034","A036","A037","A038","A039","A043","A044","A045","A046","A048","A050","A051","A052"]

# Instantiate class
# Note: this will save a config file with all relevant information and prepare folder structure
fc_parcellation = FC_Parcellation(config,source,target,'corr')

# %% [markdown]
# # Analyses
# <hr style="border:0.5px solid black">

# %% [markdown]
# ### Compute the voxelwise correlation & run clustering for each subject independently

# %%
start = time.time()
# Loop through the subjects to compute fc and clustering 
for sub_id,sub in enumerate(fc_parcellation.config['list_subjects']): 
    print(f'\033[1mSUBJECT {sub}\033[0m')
    # Compute correlation without saving files
    fc_parcellation.compute_voxelwise_fc(sub=sub, 
                                        overwrite=False)
    # Run clustering and save labels
    fc_parcellation.run_clustering(sub=sub,
                                    k_range=range(8,14),algorithm='kmeans',
                                    overwrite=False)
print("\033[1m... Operation performed in %.2f s!\033[0m" % (time.time() - start))
# Out:
# SUBJECT P030
# COMPUTE VOXELWISE FC
# Standardize = True
# Overwrite results = False
# ... FC already computed
#
# DONE
# CLUSTERING AT THE INDIVIDUAL LEVEL
# Algorithm = kmeans
# K value(s) = range(8, 14)
# Overwrite results = False
# K = 8
# ... Loading FC from file
# ... Running k-means clustering
# K = 9
# ... Loading FC from file
# ... Running k-means clustering
# K = 10
# ... Loading FC from file
# ... Running k-means clustering
# K = 11
# ... Loading FC from file
# ... Running k-means clustering
# K = 12
# ... Loading FC from file
# ... Running k-means clustering
# K = 13
# ... Loading FC from file
# ... Running k-means clustering
#
#
# SUBJECT P099
# COMPUTE VOXELWISE FC
# Standardize = True
# Overwrite results = False
# ... FC already computed
#
# DONE
# CLUSTERING AT THE INDIVIDUAL LEVEL
# Algorithm = kmeans
# K value(s) = range(8, 14)
# Overwrite results = False
# K = 8
# ... Loading FC from file
# ... Running k-means clustering
# K = 9
# ... Loading FC from file
# ... Running k-means clustering
# K = 10
# ... Loading FC from file
# ... Running k-means clustering
# K = 11
# ... Loading FC from file
# ... Running k-means clustering
# K = 12
# ... Loading FC from file
# ... Running k-means clustering
# K = 13
# ... Loading FC from file
# ... Running k-means clustering
#
#
# SUBJECT A006
# COMPUTE VOXELWISE FC
# Standardize = True
# Overwrite results = False
# ... FC already computed
#
# DONE
# CLUSTERING AT THE INDIVIDUAL LEVEL
# Algorithm = kmeans
# K value(s) = range(8, 14)
# Overwrite results = False
# K = 8
# ... Loading FC from file
# ... Running k-means clustering
# K = 9
# ... Loading FC from file
# ... Running k-means clustering
# K = 10
# ... Loading FC from file
# ... Running k-means clustering
# K = 11
# ... Loading FC from file
# ... Running k-means clustering
# K = 12
# ... Loading FC from file
# ... Running k-means clustering
# K = 13
# ... Loading FC from file
# ... Running k-means clustering
#
#
# SUBJECT A007
# COMPUTE VOXELWISE FC
# Standardize = True
# Overwrite results = False
# ... FC already computed
#
# DONE
# CLUSTERING AT THE INDIVIDUAL LEVEL
# Algorithm = kmeans
# K value(s) = range(8, 14)
# Overwrite results = False
# K = 8
# ... Loading FC from file
# ... Running k-means clustering
# K = 9
# ... Loading FC from file
# ... Running k-means clustering
# K = 10
# ... Loading FC from file
# ... Running k-means clustering
# K = 11
# ... Loading FC from file
# ... Running k-means clustering
# K = 12
# ... Loading FC from file
# ... Running k-means clustering
# K = 13
# ... Loading FC from file
# ... Running k-means clustering
#
#
# SUBJECT A008
# COMPUTE VOXELWISE FC
# Standardize = True
# Overwrite results = False
# ... FC already computed
#
# DONE
# CLUSTERING AT THE INDIVIDUAL LEVEL
# Algorithm = kmeans
# K value(s) = range(8, 14)
# Overwrite results = False
# K = 8
# ... Loading FC from file
# ... Running k-means clustering
# K = 9
# ... Loading FC from file
# ... Running k-means clustering
# K = 10
# ... Loading FC from file
# ... Running k-means clustering
# K = 11
# ... Loading FC from file
# ... Running k-means clustering
# K = 12
# ... Loading FC from file
# ... Running k-means clustering
# K = 13
# ... Loading FC from file
# ... Running k-means clustering
#
#
# SUBJECT A009
# COMPUTE VOXELWISE FC
# Standardize = True
# Overwrite results = False
# ... FC already computed
#
# DONE
# CLUSTERING AT THE INDIVIDUAL LEVEL
# Algorithm = kmeans
# K value(s) = range(8, 14)
# Overwrite results = False
# K = 8
# ... Loading FC from file
# ... Running k-means clustering
# K = 9
# ... Loading FC from file
# ... Running k-means clustering
# K = 10
# ... Loading FC from file
# ... Running k-means clustering
# K = 11
# ... Loading FC from file
# ... Running k-means clustering
# K = 12
# ... Loading FC from file
# ... Running k-means clustering
# K = 13
# ... Loading FC from file
# ... Running k-means clustering
#
#
# SUBJECT A011
# COMPUTE VOXELWISE FC
# Standardize = True
# Overwrite results = False
# ... FC already computed
#
# DONE
# CLUSTERING AT THE INDIVIDUAL LEVEL
# Algorithm = kmeans
# K value(s) = range(8, 14)
# Overwrite results = False
# K = 8
# ... Loading FC from file
# ... Running k-means clustering
# K = 9
# ... Loading FC from file
# ... Running k-means clustering
# K = 10
# ... Loading FC from file
# ... Running k-means clustering
# K = 11
# ... Loading FC from file
# ... Running k-means clustering
# K = 12
# ... Loading FC from file
# ... Running k-means clustering
# K = 13
# ... Loading FC from file
# ... Running k-means clustering
#
#
# SUBJECT A013
# COMPUTE VOXELWISE FC
# Standardize = True
# Overwrite results = False
# ... FC already computed
#
# DONE
# CLUSTERING AT THE INDIVIDUAL LEVEL
# Algorithm = kmeans
# K value(s) = range(8, 14)
# Overwrite results = False
# K = 8
# ... Loading FC from file
# ... Running k-means clustering
# K = 9
# ... Loading FC from file
# ... Running k-means clustering
# K = 10
# ... Loading FC from file
# ... Running k-means clustering
# K = 11
# ... Loading FC from file
# ... Running k-means clustering
# K = 12
# ... Loading FC from file
# ... Running k-means clustering
# K = 13
# ... Loading FC from file
# ... Running k-means clustering
#
#
# SUBJECT A023
# COMPUTE VOXELWISE FC
# Standardize = True
# Overwrite results = False
# ... FC already computed
#
# DONE
# CLUSTERING AT THE INDIVIDUAL LEVEL
# Algorithm = kmeans
# K value(s) = range(8, 14)
# Overwrite results = False
# K = 8
# ... Loading FC from file
# ... Running k-means clustering
# K = 9
# ... Loading FC from file
# ... Running k-means clustering
# K = 10
# ... Loading FC from file
# ... Running k-means clustering
# K = 11
# ... Loading FC from file
# ... Running k-means clustering
# K = 12
# ... Loading FC from file
# ... Running k-means clustering
# K = 13
# ... Loading FC from file
# ... Running k-means clustering
#
#
# SUBJECT A024
# COMPUTE VOXELWISE FC
# Standardize = True
# Overwrite results = False
# ... FC already computed
#
# DONE
# CLUSTERING AT THE INDIVIDUAL LEVEL
# Algorithm = kmeans
# K value(s) = range(8, 14)
# Overwrite results = False
# K = 8
# ... Loading FC from file
# ... Running k-means clustering
# K = 9
# ... Loading FC from file
# ... Running k-means clustering
# K = 10
# ... Loading FC from file
# ... Running k-means clustering
# K = 11
# ... Loading FC from file
# ... Running k-means clustering
# K = 12
# ... Loading FC from file
# ... Running k-means clustering
# K = 13
# ... Loading FC from file
# ... Running k-means clustering
#
#
# SUBJECT A025
# COMPUTE VOXELWISE FC
# Standardize = True
# Overwrite results = False
# ... FC already computed
#
# DONE
# CLUSTERING AT THE INDIVIDUAL LEVEL
# Algorithm = kmeans
# K value(s) = range(8, 14)
# Overwrite results = False
# K = 8
# ... Loading FC from file
# ... Running k-means clustering
# K = 9
# ... Loading FC from file
# ... Running k-means clustering
# K = 10
# ... Loading FC from file
# ... Running k-means clustering
# K = 11
# ... Loading FC from file
# ... Running k-means clustering
# K = 12
# ... Loading FC from file
# ... Running k-means clustering
# K = 13
# ... Loading FC from file
# ... Running k-means clustering
#
#
# SUBJECT A026
# COMPUTE VOXELWISE FC
# Standardize = True
# Overwrite results = False
# ... FC already computed
#
# DONE
# CLUSTERING AT THE INDIVIDUAL LEVEL
# Algorithm = kmeans
# K value(s) = range(8, 14)
# Overwrite results = False
# K = 8
# ... Loading FC from file
# ... Running k-means clustering
# K = 9
# ... Loading FC from file
# ... Running k-means clustering
# K = 10
# ... Loading FC from file
# ... Running k-means clustering
# K = 11
# ... Loading FC from file
# ... Running k-means clustering
# K = 12
# ... Loading FC from file
# ... Running k-means clustering
# K = 13
# ... Loading FC from file
# ... Running k-means clustering
#
#
# SUBJECT A027
# COMPUTE VOXELWISE FC
# Standardize = True
# Overwrite results = False
# ... FC already computed
#
# DONE
# CLUSTERING AT THE INDIVIDUAL LEVEL
# Algorithm = kmeans
# K value(s) = range(8, 14)
# Overwrite results = False
# K = 8
# ... Loading FC from file
# ... Running k-means clustering
# K = 9
# ... Loading FC from file
# ... Running k-means clustering
# K = 10
# ... Loading FC from file
# ... Running k-means clustering
# K = 11
# ... Loading FC from file
# ... Running k-means clustering
# K = 12
# ... Loading FC from file
# ... Running k-means clustering
# K = 13
# ... Loading FC from file
# ... Running k-means clustering
#
#
# SUBJECT A028
# COMPUTE VOXELWISE FC
# Standardize = True
# Overwrite results = False
# ... FC already computed
#
# DONE
# CLUSTERING AT THE INDIVIDUAL LEVEL
# Algorithm = kmeans
# K value(s) = range(8, 14)
# Overwrite results = False
# K = 8
# ... Loading FC from file
# ... Running k-means clustering
# K = 9
# ... Loading FC from file
# ... Running k-means clustering
# K = 10
# ... Loading FC from file
# ... Running k-means clustering
# K = 11
# ... Loading FC from file
# ... Running k-means clustering
# K = 12
# ... Loading FC from file
# ... Running k-means clustering
# K = 13
# ... Loading FC from file
# ... Running k-means clustering
#
#
# SUBJECT A029
# COMPUTE VOXELWISE FC
# Standardize = True
# Overwrite results = False
# ... FC already computed
#
# DONE
# CLUSTERING AT THE INDIVIDUAL LEVEL
# Algorithm = kmeans
# K value(s) = range(8, 14)
# Overwrite results = False
# K = 8
# ... Loading FC from file
# ... Running k-means clustering
# K = 9
# ... Loading FC from file
# ... Running k-means clustering
# K = 10
# ... Loading FC from file
# ... Running k-means clustering
# K = 11
# ... Loading FC from file
# ... Running k-means clustering
# K = 12
# ... Loading FC from file
# ... Running k-means clustering
# K = 13
# ... Loading FC from file
# ... Running k-means clustering
#
#
# SUBJECT A030
# COMPUTE VOXELWISE FC
# Standardize = True
# Overwrite results = False
# ... FC already computed
#
# DONE
# CLUSTERING AT THE INDIVIDUAL LEVEL
# Algorithm = kmeans
# K value(s) = range(8, 14)
# Overwrite results = False
# K = 8
# ... Loading FC from file
# ... Running k-means clustering
# K = 9
# ... Loading FC from file
# ... Running k-means clustering
# K = 10
# ... Loading FC from file
# ... Running k-means clustering
# K = 11
# ... Loading FC from file
# ... Running k-means clustering
# K = 12
# ... Loading FC from file
# ... Running k-means clustering
# K = 13
# ... Loading FC from file
# ... Running k-means clustering
#
#
# SUBJECT A032
# COMPUTE VOXELWISE FC
# Standardize = True
# Overwrite results = False
# ... FC already computed
#
# DONE
# CLUSTERING AT THE INDIVIDUAL LEVEL
# Algorithm = kmeans
# K value(s) = range(8, 14)
# Overwrite results = False
# K = 8
# ... Loading FC from file
# ... Running k-means clustering
# K = 9
# ... Loading FC from file
# ... Running k-means clustering
# K = 10
# ... Loading FC from file
# ... Running k-means clustering
# K = 11
# ... Loading FC from file
# ... Running k-means clustering
# K = 12
# ... Loading FC from file
# ... Running k-means clustering
# K = 13
# ... Loading FC from file
# ... Running k-means clustering
#
#
# SUBJECT A033
# COMPUTE VOXELWISE FC
# Standardize = True
# Overwrite results = False
# ... FC already computed
#
# DONE
# CLUSTERING AT THE INDIVIDUAL LEVEL
# Algorithm = kmeans
# K value(s) = range(8, 14)
# Overwrite results = False
# K = 8
# ... Loading FC from file
# ... Running k-means clustering
# K = 9
# ... Loading FC from file
# ... Running k-means clustering
# K = 10
# ... Loading FC from file
# ... Running k-means clustering
# K = 11
# ... Loading FC from file
# ... Running k-means clustering
# K = 12
# ... Loading FC from file
# ... Running k-means clustering
# K = 13
# ... Loading FC from file
# ... Running k-means clustering
#
#
# SUBJECT A034
# COMPUTE VOXELWISE FC
# Standardize = True
# Overwrite results = False
# ... FC already computed
#
# DONE
# CLUSTERING AT THE INDIVIDUAL LEVEL
# Algorithm = kmeans
# K value(s) = range(8, 14)
# Overwrite results = False
# K = 8
# ... Loading FC from file
# ... Running k-means clustering
# K = 9
# ... Loading FC from file
# ... Running k-means clustering
# K = 10
# ... Loading FC from file
# ... Running k-means clustering
# K = 11
# ... Loading FC from file
# ... Running k-means clustering
# K = 12
# ... Loading FC from file
# ... Running k-means clustering
# K = 13
# ... Loading FC from file
# ... Running k-means clustering
#
#
# SUBJECT A036
# COMPUTE VOXELWISE FC
# Standardize = True
# Overwrite results = False
# ... FC already computed
#
# DONE
# CLUSTERING AT THE INDIVIDUAL LEVEL
# Algorithm = kmeans
# K value(s) = range(8, 14)
# Overwrite results = False
# K = 8
# ... Loading FC from file
# ... Running k-means clustering
# K = 9
# ... Loading FC from file
# ... Running k-means clustering
# K = 10
# ... Loading FC from file
# ... Running k-means clustering
# K = 11
# ... Loading FC from file
# ... Running k-means clustering
# K = 12
# ... Loading FC from file
# ... Running k-means clustering
# K = 13
# ... Loading FC from file
# ... Running k-means clustering
#
#
# SUBJECT A037
# COMPUTE VOXELWISE FC
# Standardize = True
# Overwrite results = False
# ... FC already computed
#
# DONE
# CLUSTERING AT THE INDIVIDUAL LEVEL
# Algorithm = kmeans
# K value(s) = range(8, 14)
# Overwrite results = False
# K = 8
# ... Loading FC from file
# ... Running k-means clustering
# K = 9
# ... Loading FC from file
# ... Running k-means clustering
# K = 10
# ... Loading FC from file
# ... Running k-means clustering
# K = 11
# ... Loading FC from file
# ... Running k-means clustering
# K = 12
# ... Loading FC from file
# ... Running k-means clustering
# K = 13
# ... Loading FC from file
# ... Running k-means clustering
#
#
# SUBJECT A038
# COMPUTE VOXELWISE FC
# Standardize = True
# Overwrite results = False
# ... FC already computed
#
# DONE
# CLUSTERING AT THE INDIVIDUAL LEVEL
# Algorithm = kmeans
# K value(s) = range(8, 14)
# Overwrite results = False
# K = 8
# ... Loading FC from file
# ... Running k-means clustering
# K = 9
# ... Loading FC from file
# ... Running k-means clustering
# K = 10
# ... Loading FC from file
# ... Running k-means clustering
# K = 11
# ... Loading FC from file
# ... Running k-means clustering
# K = 12
# ... Loading FC from file
# ... Running k-means clustering
# K = 13
# ... Loading FC from file
# ... Running k-means clustering
#
#
# SUBJECT A039
# COMPUTE VOXELWISE FC
# Standardize = True
# Overwrite results = False
# ... FC already computed
#
# DONE
# CLUSTERING AT THE INDIVIDUAL LEVEL
# Algorithm = kmeans
# K value(s) = range(8, 14)
# Overwrite results = False
# K = 8
# ... Loading FC from file
# ... Running k-means clustering
# K = 9
# ... Loading FC from file
# ... Running k-means clustering
# K = 10
# ... Loading FC from file
# ... Running k-means clustering
# K = 11
# ... Loading FC from file
# ... Running k-means clustering
# K = 12
# ... Loading FC from file
# ... Running k-means clustering
# K = 13
# ... Loading FC from file
# ... Running k-means clustering
#
#
# SUBJECT A043
# COMPUTE VOXELWISE FC
# Standardize = True
# Overwrite results = False
# ... FC already computed
#
# DONE
# CLUSTERING AT THE INDIVIDUAL LEVEL
# Algorithm = kmeans
# K value(s) = range(8, 14)
# Overwrite results = False
# K = 8
# ... Loading FC from file
# ... Running k-means clustering
# K = 9
# ... Loading FC from file
# ... Running k-means clustering
# K = 10
# ... Loading FC from file
# ... Running k-means clustering
# K = 11
# ... Loading FC from file
# ... Running k-means clustering
# K = 12
# ... Loading FC from file
# ... Running k-means clustering
# K = 13
# ... Loading FC from file
# ... Running k-means clustering
#
#
# SUBJECT A044
# COMPUTE VOXELWISE FC
# Standardize = True
# Overwrite results = False
# ... FC already computed
#
# DONE
# CLUSTERING AT THE INDIVIDUAL LEVEL
# Algorithm = kmeans
# K value(s) = range(8, 14)
# Overwrite results = False
# K = 8
# ... Loading FC from file
# ... Running k-means clustering
# K = 9
# ... Loading FC from file
# ... Running k-means clustering
# K = 10
# ... Loading FC from file
# ... Running k-means clustering
# K = 11
# ... Loading FC from file
# ... Running k-means clustering
# K = 12
# ... Loading FC from file
# ... Running k-means clustering
# K = 13
# ... Loading FC from file
# ... Running k-means clustering
#
#
# SUBJECT A045
# COMPUTE VOXELWISE FC
# Standardize = True
# Overwrite results = False
# ... FC already computed
#
# DONE
# CLUSTERING AT THE INDIVIDUAL LEVEL
# Algorithm = kmeans
# K value(s) = range(8, 14)
# Overwrite results = False
# K = 8
# ... Loading FC from file
# ... Running k-means clustering
# K = 9
# ... Loading FC from file
# ... Running k-means clustering
# K = 10
# ... Loading FC from file
# ... Running k-means clustering
# K = 11
# ... Loading FC from file
# ... Running k-means clustering
# K = 12
# ... Loading FC from file
# ... Running k-means clustering
# K = 13
# ... Loading FC from file
# ... Running k-means clustering
#
#
# SUBJECT A046
# COMPUTE VOXELWISE FC
# Standardize = True
# Overwrite results = False
# ... FC already computed
#
# DONE
# CLUSTERING AT THE INDIVIDUAL LEVEL
# Algorithm = kmeans
# K value(s) = range(8, 14)
# Overwrite results = False
# K = 8
# ... Loading FC from file
# ... Running k-means clustering
# K = 9
# ... Loading FC from file
# ... Running k-means clustering
# K = 10
# ... Loading FC from file
# ... Running k-means clustering
# K = 11
# ... Loading FC from file
# ... Running k-means clustering
# K = 12
# ... Loading FC from file
# ... Running k-means clustering
# K = 13
# ... Loading FC from file
# ... Running k-means clustering
#
#
# SUBJECT A048
# COMPUTE VOXELWISE FC
# Standardize = True
# Overwrite results = False
# ... FC already computed
#
# DONE
# CLUSTERING AT THE INDIVIDUAL LEVEL
# Algorithm = kmeans
# K value(s) = range(8, 14)
# Overwrite results = False
# K = 8
# ... Loading FC from file
# ... Running k-means clustering
# K = 9
# ... Loading FC from file
# ... Running k-means clustering
# K = 10
# ... Loading FC from file
# ... Running k-means clustering
# K = 11
# ... Loading FC from file
# ... Running k-means clustering
# K = 12
# ... Loading FC from file
# ... Running k-means clustering
# K = 13
# ... Loading FC from file
# ... Running k-means clustering
#
#
# SUBJECT A050
# COMPUTE VOXELWISE FC
# Standardize = True
# Overwrite results = False
# ... FC already computed
#
# DONE
# CLUSTERING AT THE INDIVIDUAL LEVEL
# Algorithm = kmeans
# K value(s) = range(8, 14)
# Overwrite results = False
# K = 8
# ... Loading FC from file
# ... Running k-means clustering
# K = 9
# ... Loading FC from file
# ... Running k-means clustering
# K = 10
# ... Loading FC from file
# ... Running k-means clustering
# K = 11
# ... Loading FC from file
# ... Running k-means clustering
# K = 12
# ... Loading FC from file
# ... Running k-means clustering
# K = 13
# ... Loading FC from file
# ... Running k-means clustering
#
#
# SUBJECT A051
# COMPUTE VOXELWISE FC
# Standardize = True
# Overwrite results = False
# ... FC already computed
#
# DONE
# CLUSTERING AT THE INDIVIDUAL LEVEL
# Algorithm = kmeans
# K value(s) = range(8, 14)
# Overwrite results = False
# K = 8
# ... Loading FC from file
# ... Running k-means clustering
# K = 9
# ... Loading FC from file
# ... Running k-means clustering
# K = 10
# ... Loading FC from file
# ... Running k-means clustering
# K = 11
# ... Loading FC from file
# ... Running k-means clustering
# K = 12
# ... Loading FC from file
# ... Running k-means clustering
# K = 13
# ... Loading FC from file
# ... Running k-means clustering
#
#
# SUBJECT A052
# COMPUTE VOXELWISE FC
# Standardize = True
# Overwrite results = False
# ... FC already computed
#
# DONE
# CLUSTERING AT THE INDIVIDUAL LEVEL
# Algorithm = kmeans
# K value(s) = range(8, 14)
# Overwrite results = False
# K = 8
# ... Loading FC from file
# ... Running k-means clustering
# K = 9
# ... Loading FC from file
# ... Running k-means clustering
# K = 10
# ... Loading FC from file
# ... Running k-means clustering
# K = 11
# ... Loading FC from file
# ... Running k-means clustering
# K = 12
# ... Loading FC from file
# ... Running k-means clustering
# K = 13
# ... Loading FC from file
# ... Running k-means clustering
#
#
# ... Operation performed in 776286.41 s!

# %% [markdown]
# ### Compute the group-level clustering and generate corresponding maps

# %%
fc_parcellation.group_clustering(k_range=range(8,14),indiv_algorithm='kmeans',overwrite=False)
# Out:
# CLUSTERING AT THE GROUP LEVEL
# K value(s) = range(8, 14)
# Overwrite results = False
# WARNING: THESE RESULTS CHANGE IF GROUP CHANGES, MAKE SURE YOU ARE USING THE SAME SUBJECTS
#
# K = 8
# ... Computing hierarchical clustering and relabeling
# ...... Loading all subjects
# ...... Clustering on all labels
# ...... Computing cophenetic correlation
# ...... Relabeling
# ...... Computing validity
# /home/kinany/anaconda3/lib/python3.9/site-packages/nilearn/masking.py:974: UserWarning: Data array used to create a new image contains 64-bit ints. This is likely due to creating the array with numpy and passing `int` as the `dtype`. Many tools such as FSL and SPM cannot deal with int64 in Nifti images, so for compatibility the data has been converted to int32.
#   return new_img_like(mask_img, unmasked, affine)
# K = 9
# ... Computing hierarchical clustering and relabeling
# ...... Loading all subjects
# ...... Clustering on all labels
# ...... Computing cophenetic correlation
# ...... Relabeling
# ...... Computing validity
# /home/kinany/anaconda3/lib/python3.9/site-packages/nilearn/masking.py:974: UserWarning: Data array used to create a new image contains 64-bit ints. This is likely due to creating the array with numpy and passing `int` as the `dtype`. Many tools such as FSL and SPM cannot deal with int64 in Nifti images, so for compatibility the data has been converted to int32.
#   return new_img_like(mask_img, unmasked, affine)
# K = 10
# ... Computing hierarchical clustering and relabeling
# ...... Loading all subjects
# ...... Clustering on all labels
# ...... Computing cophenetic correlation
# ...... Relabeling
# ...... Computing validity
# /home/kinany/anaconda3/lib/python3.9/site-packages/nilearn/masking.py:974: UserWarning: Data array used to create a new image contains 64-bit ints. This is likely due to creating the array with numpy and passing `int` as the `dtype`. Many tools such as FSL and SPM cannot deal with int64 in Nifti images, so for compatibility the data has been converted to int32.
#   return new_img_like(mask_img, unmasked, affine)
# K = 11
# ... Computing hierarchical clustering and relabeling
# ...... Loading all subjects
# ...... Clustering on all labels
# ...... Computing cophenetic correlation
# ...... Relabeling
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[248], line 1
# ----> 1 fc_parcellation.group_clustering(k_range=range(8,14),indiv_algorithm='kmeans',overwrite=False)
#
# File /media/miplab-nas2/Data3/BMPD/hc_project/analysis/code/fc_based_parcellation.py:401, in FC_Parcellation.group_clustering(self, k_range, indiv_algorithm, poscorr, linkage, overwrite)
#     399 # iterate over individual participant labels (rows)
#     400 for label in indiv_labels_all:
# --> 401     x, acc = self._relabel(reference=group_labels, x=label)
#     402     indiv_labels_relabeled = np.vstack([indiv_labels_relabeled , x])
#     404 mode, _ = stats.mode(indiv_labels_relabeled, axis=0, keepdims=False)
#
# File /media/miplab-nas2/Data3/BMPD/hc_project/analysis/code/fc_based_parcellation.py:1011, in _relabel(self, reference, x)
#    1007     y[x == k] = v
#    1009 _accuracy = np.sum(y == reference) / len(reference)
# -> 1011 if _accuracy > accuracy:
#    1012     accuracy = _accuracy
#    1013     relabeled = y.copy()
#
# KeyboardInterrupt:

# %%
fc_parcellation.prepare_target_maps(label_type='indiv',indiv_algorithm='kmeans',k_range=[3,4,6],overwrite=False)
# Out:
# PREPARE TARGET MAPS
# Type of source labels = indiv
# K value(s) = [3, 4, 6]
# Overwrite results = False
# K = 3
# ... Computing target maps
# ...... Subject P030
# ...... Subject P099
# ...... Subject A006
# ...... Subject A007
# ...... Subject A008
# ...... Subject A009
# ...... Subject A011
# ...... Subject A013
# ...... Subject A023
# ...... Subject A024
# ...... Subject A025
# ...... Subject A026
# ...... Subject A027
# ...... Subject A028
# ...... Subject A029
# ...... Subject A030
# ...... Subject A032
# ...... Subject A033
# ...... Subject A034
# ...... Subject A036
# ...... Subject A037
# ...... Subject A038
# ...... Subject A039
# ...... Subject A043
# ...... Subject A044
# ...... Subject A045
# ...... Subject A046
# ...... Subject A048
# ...... Subject A050
# ...... Subject A051
# ...... Subject A052
# K = 4
# ... Computing target maps
# ...... Subject P030
# ...... Subject P099
# ...... Subject A006
# ...... Subject A007
# ...... Subject A008
# ...... Subject A009
# ...... Subject A011
# ...... Subject A013
# ...... Subject A023
# ...... Subject A024
# ...... Subject A025
# ...... Subject A026
# ...... Subject A027
# ...... Subject A028
# ...... Subject A029
# ...... Subject A030
# ...... Subject A032
# ...... Subject A033
# ...... Subject A034
# ...... Subject A036
# ...... Subject A037
# ...... Subject A038
# ...... Subject A039
# ...... Subject A043
# ...... Subject A044
# ...... Subject A045
# ...... Subject A046
# ...... Subject A048
# ...... Subject A050
# ...... Subject A051
# ...... Subject A052
# K = 6
# ... Computing target maps
# ...... Subject P030
# ...... Subject P099
# ...... Subject A006
# ...... Subject A007
# ...... Subject A008
# ...... Subject A009
# ...... Subject A011
# ...... Subject A013
# ...... Subject A023
# ...... Subject A024
# ...... Subject A025
# ...... Subject A026
# ...... Subject A027
# ...... Subject A028
# ...... Subject A029
# ...... Subject A030
# ...... Subject A032
# ...... Subject A033
# ...... Subject A034
# ...... Subject A036
# ...... Subject A037
# ...... Subject A038
# ...... Subject A039
# ...... Subject A043
# ...... Subject A044
# ...... Subject A045
# ...... Subject A046
# ...... Subject A048
# ...... Subject A050
# ...... Subject A051
# ...... Subject A052
# DONE

# %%
fc_parcellation.prepare_target_maps(label_type='group_mode',indiv_algorithm='kmeans',k_range=[3,4,6],overwrite=False)
# Out:
# PREPARE TARGET MAPS
# Type of source labels = group_mode
# K value(s) = [3, 4, 6]
# Overwrite results = False
# K = 3
# ... Computing target maps
# ...... Subject P030
# ...... Subject P099
# ...... Subject A006
# ...... Subject A007
# ...... Subject A008
# ...... Subject A009
# ...... Subject A011
# ...... Subject A013
# ...... Subject A023
# ...... Subject A024
# ...... Subject A025
# ...... Subject A026
# ...... Subject A027
# ...... Subject A028
# ...... Subject A029
# ...... Subject A030
# ...... Subject A032
# ...... Subject A033
# ...... Subject A034
# ...... Subject A036
# ...... Subject A037
# ...... Subject A038
# ...... Subject A039
# ...... Subject A043
# ...... Subject A044
# ...... Subject A045
# ...... Subject A046
# ...... Subject A048
# ...... Subject A050
# ...... Subject A051
# ...... Subject A052
# K = 4
# ... Computing target maps
# ...... Subject P030
# ...... Subject P099
# ...... Subject A006
# ...... Subject A007
# ...... Subject A008
# ...... Subject A009
# ...... Subject A011
# ...... Subject A013
# ...... Subject A023
# ...... Subject A024
# ...... Subject A025
# ...... Subject A026
# ...... Subject A027
# ...... Subject A028
# ...... Subject A029
# ...... Subject A030
# ...... Subject A032
# ...... Subject A033
# ...... Subject A034
# ...... Subject A036
# ...... Subject A037
# ...... Subject A038
# ...... Subject A039
# ...... Subject A043
# ...... Subject A044
# ...... Subject A045
# ...... Subject A046
# ...... Subject A048
# ...... Subject A050
# ...... Subject A051
# ...... Subject A052
# K = 6
# ... Computing target maps
# ...... Subject P030
# ...... Subject P099
# ...... Subject A006
# ...... Subject A007
# ...... Subject A008
# ...... Subject A009
# ...... Subject A011
# ...... Subject A013
# ...... Subject A023
# ...... Subject A024
# ...... Subject A025
# ...... Subject A026
# ...... Subject A027
# ...... Subject A028
# ...... Subject A029
# ...... Subject A030
# ...... Subject A032
# ...... Subject A033
# ...... Subject A034
# ...... Subject A036
# ...... Subject A037
# ...... Subject A038
# ...... Subject A039
# ...... Subject A043
# ...... Subject A044
# ...... Subject A045
# ...... Subject A046
# ...... Subject A048
# ...... Subject A050
# ...... Subject A051
# ...... Subject A052
# DONE

# %% [markdown]
# ### Statistics and WTA analysis

# %%
fc_parcellation.stats_target_maps(label_type='group_mode',indiv_algorithm='kmeans',k_range=6,overwrite=False)
# Out:
# RUN STATISTICAL ANALYSIS
# Type of source labels = group_mode
# K value(s) = 6
# Overwrite results = False
# K = 6
# ... Merging target files
# fslmerge -t /media/miplab-nas2/Data3/BMPD/hc_project//brain_spine/results/fc_parcellation//corr/C1toC7_gm_V_to_wholebrain/target//K6/group_mode_labels/maps_indiv/C1toC7_gm_V_to_wholebrain_all_kmeans_group_mode_labels_targetmap_K6_1.nii.gz /media/miplab-nas2/Data3/BMPD/hc_project//brain_spine/results/fc_parcellation//corr/C1toC7_gm_V_to_wholebrain/target//K6/group_mode_labels/maps_indiv/C1toC7_gm_V_to_wholebrain_*_kmeans_group_mode_labels_targetmap_K6_1.nii.gz
# ... Running statistical analysis
# randomise options: -i /media/miplab-nas2/Data3/BMPD/hc_project//brain_spine/results/fc_parcellation//corr/C1toC7_gm_V_to_wholebrain/target//K6/group_mode_labels/maps_indiv/C1toC7_gm_V_to_wholebrain_all_kmeans_group_mode_labels_targetmap_K6_1.nii.gz -m /media/miplab-nas2/Data3/BMPD/hc_project//analysis/masks/brain_old_3mm/MNI_GM_3mm.nii.gz -o /media/miplab-nas2/Data3/BMPD/hc_project//brain_spine/results/fc_parcellation//corr/C1toC7_gm_V_to_wholebrain/target//K6/group_mode_labels/stats/kmeans/K6_1 -1
# Loading Data:
# Data loaded
# One-sample design detected; sign-flipping instead of permuting.
# 2.14748e+09 sign-flips required for exhaustive test of t-test 1
# Doing 5000 random permutations
# Warning! No output options selected. Outputing raw tstat only
# Starting permutation 1 (Unpermuted data)
# Finished, exiting.
# ... Merging target files
# fslmerge -t /media/miplab-nas2/Data3/BMPD/hc_project//brain_spine/results/fc_parcellation//corr/C1toC7_gm_V_to_wholebrain/target//K6/group_mode_labels/maps_indiv/C1toC7_gm_V_to_wholebrain_all_kmeans_group_mode_labels_targetmap_K6_2.nii.gz /media/miplab-nas2/Data3/BMPD/hc_project//brain_spine/results/fc_parcellation//corr/C1toC7_gm_V_to_wholebrain/target//K6/group_mode_labels/maps_indiv/C1toC7_gm_V_to_wholebrain_*_kmeans_group_mode_labels_targetmap_K6_2.nii.gz
# ... Running statistical analysis
# randomise options: -i /media/miplab-nas2/Data3/BMPD/hc_project//brain_spine/results/fc_parcellation//corr/C1toC7_gm_V_to_wholebrain/target//K6/group_mode_labels/maps_indiv/C1toC7_gm_V_to_wholebrain_all_kmeans_group_mode_labels_targetmap_K6_2.nii.gz -m /media/miplab-nas2/Data3/BMPD/hc_project//analysis/masks/brain_old_3mm/MNI_GM_3mm.nii.gz -o /media/miplab-nas2/Data3/BMPD/hc_project//brain_spine/results/fc_parcellation//corr/C1toC7_gm_V_to_wholebrain/target//K6/group_mode_labels/stats/kmeans/K6_2 -1
# Loading Data:
# Data loaded
# One-sample design detected; sign-flipping instead of permuting.
# 2.14748e+09 sign-flips required for exhaustive test of t-test 1
# Doing 5000 random permutations
# Warning! No output options selected. Outputing raw tstat only
# Starting permutation 1 (Unpermuted data)
# Finished, exiting.
# ... Merging target files
# fslmerge -t /media/miplab-nas2/Data3/BMPD/hc_project//brain_spine/results/fc_parcellation//corr/C1toC7_gm_V_to_wholebrain/target//K6/group_mode_labels/maps_indiv/C1toC7_gm_V_to_wholebrain_all_kmeans_group_mode_labels_targetmap_K6_3.nii.gz /media/miplab-nas2/Data3/BMPD/hc_project//brain_spine/results/fc_parcellation//corr/C1toC7_gm_V_to_wholebrain/target//K6/group_mode_labels/maps_indiv/C1toC7_gm_V_to_wholebrain_*_kmeans_group_mode_labels_targetmap_K6_3.nii.gz
# ... Running statistical analysis
# randomise options: -i /media/miplab-nas2/Data3/BMPD/hc_project//brain_spine/results/fc_parcellation//corr/C1toC7_gm_V_to_wholebrain/target//K6/group_mode_labels/maps_indiv/C1toC7_gm_V_to_wholebrain_all_kmeans_group_mode_labels_targetmap_K6_3.nii.gz -m /media/miplab-nas2/Data3/BMPD/hc_project//analysis/masks/brain_old_3mm/MNI_GM_3mm.nii.gz -o /media/miplab-nas2/Data3/BMPD/hc_project//brain_spine/results/fc_parcellation//corr/C1toC7_gm_V_to_wholebrain/target//K6/group_mode_labels/stats/kmeans/K6_3 -1
# Loading Data:
# Data loaded
# One-sample design detected; sign-flipping instead of permuting.
# 2.14748e+09 sign-flips required for exhaustive test of t-test 1
# Doing 5000 random permutations
# Warning! No output options selected. Outputing raw tstat only
# Starting permutation 1 (Unpermuted data)
# Finished, exiting.
# ... Merging target files
# fslmerge -t /media/miplab-nas2/Data3/BMPD/hc_project//brain_spine/results/fc_parcellation//corr/C1toC7_gm_V_to_wholebrain/target//K6/group_mode_labels/maps_indiv/C1toC7_gm_V_to_wholebrain_all_kmeans_group_mode_labels_targetmap_K6_4.nii.gz /media/miplab-nas2/Data3/BMPD/hc_project//brain_spine/results/fc_parcellation//corr/C1toC7_gm_V_to_wholebrain/target//K6/group_mode_labels/maps_indiv/C1toC7_gm_V_to_wholebrain_*_kmeans_group_mode_labels_targetmap_K6_4.nii.gz
# ... Running statistical analysis
# randomise options: -i /media/miplab-nas2/Data3/BMPD/hc_project//brain_spine/results/fc_parcellation//corr/C1toC7_gm_V_to_wholebrain/target//K6/group_mode_labels/maps_indiv/C1toC7_gm_V_to_wholebrain_all_kmeans_group_mode_labels_targetmap_K6_4.nii.gz -m /media/miplab-nas2/Data3/BMPD/hc_project//analysis/masks/brain_old_3mm/MNI_GM_3mm.nii.gz -o /media/miplab-nas2/Data3/BMPD/hc_project//brain_spine/results/fc_parcellation//corr/C1toC7_gm_V_to_wholebrain/target//K6/group_mode_labels/stats/kmeans/K6_4 -1
# Loading Data:
# Data loaded
# One-sample design detected; sign-flipping instead of permuting.
# 2.14748e+09 sign-flips required for exhaustive test of t-test 1
# Doing 5000 random permutations
# Warning! No output options selected. Outputing raw tstat only
# Starting permutation 1 (Unpermuted data)
# Finished, exiting.
# ... Merging target files
# fslmerge -t /media/miplab-nas2/Data3/BMPD/hc_project//brain_spine/results/fc_parcellation//corr/C1toC7_gm_V_to_wholebrain/target//K6/group_mode_labels/maps_indiv/C1toC7_gm_V_to_wholebrain_all_kmeans_group_mode_labels_targetmap_K6_5.nii.gz /media/miplab-nas2/Data3/BMPD/hc_project//brain_spine/results/fc_parcellation//corr/C1toC7_gm_V_to_wholebrain/target//K6/group_mode_labels/maps_indiv/C1toC7_gm_V_to_wholebrain_*_kmeans_group_mode_labels_targetmap_K6_5.nii.gz
# ... Running statistical analysis
# randomise options: -i /media/miplab-nas2/Data3/BMPD/hc_project//brain_spine/results/fc_parcellation//corr/C1toC7_gm_V_to_wholebrain/target//K6/group_mode_labels/maps_indiv/C1toC7_gm_V_to_wholebrain_all_kmeans_group_mode_labels_targetmap_K6_5.nii.gz -m /media/miplab-nas2/Data3/BMPD/hc_project//analysis/masks/brain_old_3mm/MNI_GM_3mm.nii.gz -o /media/miplab-nas2/Data3/BMPD/hc_project//brain_spine/results/fc_parcellation//corr/C1toC7_gm_V_to_wholebrain/target//K6/group_mode_labels/stats/kmeans/K6_5 -1
# Loading Data:
# Data loaded
# One-sample design detected; sign-flipping instead of permuting.
# 2.14748e+09 sign-flips required for exhaustive test of t-test 1
# Doing 5000 random permutations
# Warning! No output options selected. Outputing raw tstat only
# Starting permutation 1 (Unpermuted data)
# Finished, exiting.
# ... Merging target files
# fslmerge -t /media/miplab-nas2/Data3/BMPD/hc_project//brain_spine/results/fc_parcellation//corr/C1toC7_gm_V_to_wholebrain/target//K6/group_mode_labels/maps_indiv/C1toC7_gm_V_to_wholebrain_all_kmeans_group_mode_labels_targetmap_K6_6.nii.gz /media/miplab-nas2/Data3/BMPD/hc_project//brain_spine/results/fc_parcellation//corr/C1toC7_gm_V_to_wholebrain/target//K6/group_mode_labels/maps_indiv/C1toC7_gm_V_to_wholebrain_*_kmeans_group_mode_labels_targetmap_K6_6.nii.gz
# ... Running statistical analysis
# randomise options: -i /media/miplab-nas2/Data3/BMPD/hc_project//brain_spine/results/fc_parcellation//corr/C1toC7_gm_V_to_wholebrain/target//K6/group_mode_labels/maps_indiv/C1toC7_gm_V_to_wholebrain_all_kmeans_group_mode_labels_targetmap_K6_6.nii.gz -m /media/miplab-nas2/Data3/BMPD/hc_project//analysis/masks/brain_old_3mm/MNI_GM_3mm.nii.gz -o /media/miplab-nas2/Data3/BMPD/hc_project//brain_spine/results/fc_parcellation//corr/C1toC7_gm_V_to_wholebrain/target//K6/group_mode_labels/stats/kmeans/K6_6 -1
# Loading Data:
# Data loaded
# One-sample design detected; sign-flipping instead of permuting.
# 2.14748e+09 sign-flips required for exhaustive test of t-test 1
# Doing 5000 random permutations
# Warning! No output options selected. Outputing raw tstat only
# Starting permutation 1 (Unpermuted data)
# Finished, exiting.
# DONE

# %%
fc_parcellation.winner_takes_all(label_type='group_mode',indiv_algorithm='kmeans',apply_threshold=1,k=7, order=[6,5,4,3,7,1,2], overwrite=True)
# Out:
# RUN WINNER-TAKES-ALL ANALYSIS
# Type of source labels = group_mode
# K value = 7
# Overwrite results = True
# K1 will have a value of 6
# K2 will have a value of 5
# K3 will have a value of 4
# K4 will have a value of 3
# K5 will have a value of 7
# K6 will have a value of 1
# K7 will have a value of 2
# KeyboardInterrupt

# %% [markdown]
# # Plotting
# <hr style="border:0.5px solid black">

# %% [markdown]
# ### WTA maps

# %%
fc_parcellation.plot_brain_map(showing='target',label_type='group_mode',indiv_algorithm='kmeans', k=7, save_figure=True)

# %% [markdown]
# ### Plot label maps

# %%
fc_parcellation.plot_spinal_map(showing='source',indiv_algorithm='kmeans', k=7, order=[6,5,4,3,7,1,2], save_figure=True)
# Out:
# RUN PLOTTING SPINAL MAPS
# K value = 7
# Showing = source
# Save figure = True
# The plotting is displayed in neurological orientation (Left > Right)

# %% [markdown]
# ### Validity
# <hr style="border:0.5px solid black">

# %% [markdown]
# ### Plot validity metrics

# %%
fc_parcellation.plot_validity(k_range=range(2,14),internal=["SSE", "silhouette", "davies", "calinski"], group=["ami_mode", "ari_mode","ami_agglom", "ari_agglom", "corr"], save_figures=True)
# Out:
# VALIDITY METRICS
# K value(s) = range(2, 14)
# Saving figures = True
