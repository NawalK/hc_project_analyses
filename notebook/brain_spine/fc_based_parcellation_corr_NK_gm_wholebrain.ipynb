# %% [markdown]
# # <font color=black> Analysis - FC-based parcellation using correlation </font>
# <hr style="border:1px solid black">

# %%
import sys,json
import glob, os
import numpy as np
import nibabel as nib
import time
from nilearn import datasets, plotting, image, surface
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap

sys.path.append('/media/miplab-nas2/Data3/BMPD/hc_project/analysis/code/')

from fc_based_parcellation import FC_Parcellation

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Initialization
# <hr style="border:0.5px solid black">

# %% [markdown]
# ### Load existing configuration file ...

# %%
# Load the config file with all information
filetag = "C1toC7_gm_V_to_wholebrain"
with open('../../../brain_spine/results/fc_parcellation/corr/' + filetag + '/config_' + filetag + '.json') as config_file:
    config = json.load(config_file)
source = 'spinalcord'
target = 'brain'

# %% [markdown]
# ### ... or build new one

# %%
# Load the config file with all information
with open('../../config/config_fc_based_parcellation_NK.json') as config_file:
    config = json.load(config_file)
# Define tag of this analysis (used for saving)
config['output_tag'] = "C1toC7_gm_07_notsmoothed_to_wholebrain"
# Define source, target, and the corresponding masks
source = 'spinalcord'
target = 'brain'
# Note: paths should be with respect to main directory
config['file_tag']['spinalcord'] = "_task-rest_bold_stc_sc_moco_brsc_BP_inTemplate.nii.gz"
config['file_tag']['brain'] = "_task-rest_bold_stc_brain_moco_brsc_BP_reg_SPM_inTemplate3mm_s.nii.gz"

config['masks']['source'] = "/templates/PAM50_hc_project/template/PAM50_gm_bin07_C1C7.nii.gz"
config['masks']['target'] = "/analysis/masks/brain_old_3mm/MNI_GM_3mm.nii.gz"

config['list_subjects'] = ["P030", "P099","A006","A007","A008","A009","A011","A013","A023","A024","A025","A026","A027","A028","A029","A030","A032","A033","A034","A036","A037","A038","A039","A043","A044","A045","A046","A048","A050","A051","A052"]

# %% [markdown]
# ### Instantiate class
# _Note: this will save a config file with all relevant information and prepare folder structure_

# %%
fc_parcellation = FC_Parcellation(config,source,target,'corr')

# %% [markdown]
# # Analyses
# <hr style="border:0.5px solid black">

# %% [markdown]
# ### Compute the voxelwise correlation & run clustering for each subject independently

# %%
start = time.time()
# Loop through the subjects to compute fc and clustering 
for sub_id,sub in enumerate(fc_parcellation.config['list_subjects']): 
    print(f'\033[1mSUBJECT {sub}\033[0m')
    # Compute correlation without saving files
    fc_parcellation.compute_voxelwise_fc(sub=sub, 
                                        overwrite=False)
    # Run clustering and save labels
    fc_parcellation.run_clustering(sub=sub,
                                    k_range=7,algorithm='kmeans',
                                    overwrite=False)
print("\033[1m... Operation performed in %.2f s!\033[0m" % (time.time() - start))
# Out:
# SUBJECT P030
# COMPUTE VOXELWISE FC
# Standardize = True
# Overwrite results = False
# ... Loading data
# ... Computing FC for all possibilities
# ... Metric: correlation
# ... Fisher transforming correlations
#
# DONE
# CLUSTERING AT THE INDIVIDUAL LEVEL
# Algorithm = kmeans
# K value(s) = 7
# Overwrite results = False
# K = 7
# ... Loading FC from file
# ... Running k-means clustering
#
#
# SUBJECT P099
# COMPUTE VOXELWISE FC
# Standardize = True
# Overwrite results = False
# ... Loading data
# ... Computing FC for all possibilities
# ... Metric: correlation
# ... Fisher transforming correlations
#
# DONE
# CLUSTERING AT THE INDIVIDUAL LEVEL
# Algorithm = kmeans
# K value(s) = 7
# Overwrite results = False
# K = 7
# ... Loading FC from file
# ... Running k-means clustering
#
#
# SUBJECT A006
# COMPUTE VOXELWISE FC
# Standardize = True
# Overwrite results = False
# ... Loading data
# ... Computing FC for all possibilities
# ... Metric: correlation
# ... Fisher transforming correlations
#
# DONE
# CLUSTERING AT THE INDIVIDUAL LEVEL
# Algorithm = kmeans
# K value(s) = 7
# Overwrite results = False
# K = 7
# ... Loading FC from file
# ... Running k-means clustering
#
#
# SUBJECT A007
# COMPUTE VOXELWISE FC
# Standardize = True
# Overwrite results = False
# ... Loading data
# ... Computing FC for all possibilities
# ... Metric: correlation
# ... Fisher transforming correlations
#
# DONE
# CLUSTERING AT THE INDIVIDUAL LEVEL
# Algorithm = kmeans
# K value(s) = 7
# Overwrite results = False
# K = 7
# ... Loading FC from file
# ... Running k-means clustering
#
#
# SUBJECT A008
# COMPUTE VOXELWISE FC
# Standardize = True
# Overwrite results = False
# ... Loading data
# ... Computing FC for all possibilities
# ... Metric: correlation
# ... Fisher transforming correlations
#
# DONE
# CLUSTERING AT THE INDIVIDUAL LEVEL
# Algorithm = kmeans
# K value(s) = 7
# Overwrite results = False
# K = 7
# ... Loading FC from file
# ... Running k-means clustering
#
#
# SUBJECT A009
# COMPUTE VOXELWISE FC
# Standardize = True
# Overwrite results = False
# ... Loading data
# ... Computing FC for all possibilities
# ... Metric: correlation
# ... Fisher transforming correlations
#
# DONE
# CLUSTERING AT THE INDIVIDUAL LEVEL
# Algorithm = kmeans
# K value(s) = 7
# Overwrite results = False
# K = 7
# ... Loading FC from file
# ... Running k-means clustering
#
#
# SUBJECT A011
# COMPUTE VOXELWISE FC
# Standardize = True
# Overwrite results = False
# ... Loading data
# ... Computing FC for all possibilities
# ... Metric: correlation
# ... Fisher transforming correlations
#
# DONE
# CLUSTERING AT THE INDIVIDUAL LEVEL
# Algorithm = kmeans
# K value(s) = 7
# Overwrite results = False
# K = 7
# ... Loading FC from file
# ... Running k-means clustering
#
#
# SUBJECT A013
# COMPUTE VOXELWISE FC
# Standardize = True
# Overwrite results = False
# ... Loading data
# ... Computing FC for all possibilities
# ... Metric: correlation
# ... Fisher transforming correlations
#
# DONE
# CLUSTERING AT THE INDIVIDUAL LEVEL
# Algorithm = kmeans
# K value(s) = 7
# Overwrite results = False
# K = 7
# ... Loading FC from file
# ... Running k-means clustering
#
#
# SUBJECT A023
# COMPUTE VOXELWISE FC
# Standardize = True
# Overwrite results = False
# ... Loading data
# ... Computing FC for all possibilities
# ... Metric: correlation
# ... Fisher transforming correlations
#
# DONE
# CLUSTERING AT THE INDIVIDUAL LEVEL
# Algorithm = kmeans
# K value(s) = 7
# Overwrite results = False
# K = 7
# ... Loading FC from file
# ... Running k-means clustering
#
#
# SUBJECT A024
# COMPUTE VOXELWISE FC
# Standardize = True
# Overwrite results = False
# ... Loading data
# ... Computing FC for all possibilities
# ... Metric: correlation
# ... Fisher transforming correlations
#
# DONE
# CLUSTERING AT THE INDIVIDUAL LEVEL
# Algorithm = kmeans
# K value(s) = 7
# Overwrite results = False
# K = 7
# ... Loading FC from file
# ... Running k-means clustering
#
#
# SUBJECT A025
# COMPUTE VOXELWISE FC
# Standardize = True
# Overwrite results = False
# ... Loading data
# ... Computing FC for all possibilities
# ... Metric: correlation
# ... Fisher transforming correlations
#
# DONE
# CLUSTERING AT THE INDIVIDUAL LEVEL
# Algorithm = kmeans
# K value(s) = 7
# Overwrite results = False
# K = 7
# ... Loading FC from file
# ... Running k-means clustering
#
#
# SUBJECT A026
# COMPUTE VOXELWISE FC
# Standardize = True
# Overwrite results = False
# ... Loading data
# ... Computing FC for all possibilities
# ... Metric: correlation
# ... Fisher transforming correlations
#
# DONE
# CLUSTERING AT THE INDIVIDUAL LEVEL
# Algorithm = kmeans
# K value(s) = 7
# Overwrite results = False
# K = 7
# ... Loading FC from file
# ... Running k-means clustering
#
#
# SUBJECT A027
# COMPUTE VOXELWISE FC
# Standardize = True
# Overwrite results = False
# ... Loading data
# ... Computing FC for all possibilities
# ... Metric: correlation
# ... Fisher transforming correlations
#
# DONE
# CLUSTERING AT THE INDIVIDUAL LEVEL
# Algorithm = kmeans
# K value(s) = 7
# Overwrite results = False
# K = 7
# ... Loading FC from file
# ... Running k-means clustering
#
#
# SUBJECT A028
# COMPUTE VOXELWISE FC
# Standardize = True
# Overwrite results = False
# ... Loading data
# ... Computing FC for all possibilities
# ... Metric: correlation
# ... Fisher transforming correlations
#
# DONE
# CLUSTERING AT THE INDIVIDUAL LEVEL
# Algorithm = kmeans
# K value(s) = 7
# Overwrite results = False
# K = 7
# ... Loading FC from file
# ... Running k-means clustering
#
#
# SUBJECT A029
# COMPUTE VOXELWISE FC
# Standardize = True
# Overwrite results = False
# ... Loading data
# ... Computing FC for all possibilities
# ... Metric: correlation
# ... Fisher transforming correlations
#
# DONE
# CLUSTERING AT THE INDIVIDUAL LEVEL
# Algorithm = kmeans
# K value(s) = 7
# Overwrite results = False
# K = 7
# ... Loading FC from file
# ... Running k-means clustering
#
#
# SUBJECT A030
# COMPUTE VOXELWISE FC
# Standardize = True
# Overwrite results = False
# ... Loading data
# ... Computing FC for all possibilities
# ... Metric: correlation
# ... Fisher transforming correlations
#
# DONE
# CLUSTERING AT THE INDIVIDUAL LEVEL
# Algorithm = kmeans
# K value(s) = 7
# Overwrite results = False
# K = 7
# ... Loading FC from file
# ... Running k-means clustering
#
#
# SUBJECT A032
# COMPUTE VOXELWISE FC
# Standardize = True
# Overwrite results = False
# ... Loading data
# ... Computing FC for all possibilities
# ... Metric: correlation
# ... Fisher transforming correlations
#
# DONE
# CLUSTERING AT THE INDIVIDUAL LEVEL
# Algorithm = kmeans
# K value(s) = 7
# Overwrite results = False
# K = 7
# ... Loading FC from file
# ... Running k-means clustering
#
#
# SUBJECT A033
# COMPUTE VOXELWISE FC
# Standardize = True
# Overwrite results = False
# ... Loading data
# ... Computing FC for all possibilities
# ... Metric: correlation
# ... Fisher transforming correlations
#
# DONE
# CLUSTERING AT THE INDIVIDUAL LEVEL
# Algorithm = kmeans
# K value(s) = 7
# Overwrite results = False
# K = 7
# ... Loading FC from file
# ... Running k-means clustering
#
#
# SUBJECT A034
# COMPUTE VOXELWISE FC
# Standardize = True
# Overwrite results = False
# ... Loading data
# ... Computing FC for all possibilities
# ... Metric: correlation
# ... Fisher transforming correlations
#
# DONE
# CLUSTERING AT THE INDIVIDUAL LEVEL
# Algorithm = kmeans
# K value(s) = 7
# Overwrite results = False
# K = 7
# ... Loading FC from file
# ... Running k-means clustering
#
#
# SUBJECT A036
# COMPUTE VOXELWISE FC
# Standardize = True
# Overwrite results = False
# ... Loading data
# ... Computing FC for all possibilities
# ... Metric: correlation
# ... Fisher transforming correlations
#
# DONE
# CLUSTERING AT THE INDIVIDUAL LEVEL
# Algorithm = kmeans
# K value(s) = 7
# Overwrite results = False
# K = 7
# ... Loading FC from file
# ... Running k-means clustering
#
#
# SUBJECT A037
# COMPUTE VOXELWISE FC
# Standardize = True
# Overwrite results = False
# ... Loading data
# ... Computing FC for all possibilities
# ... Metric: correlation
# ... Fisher transforming correlations
#
# DONE
# CLUSTERING AT THE INDIVIDUAL LEVEL
# Algorithm = kmeans
# K value(s) = 7
# Overwrite results = False
# K = 7
# ... Loading FC from file
# ... Running k-means clustering
#
#
# SUBJECT A038
# COMPUTE VOXELWISE FC
# Standardize = True
# Overwrite results = False
# ... Loading data
# ... Computing FC for all possibilities
# ... Metric: correlation
# ... Fisher transforming correlations
#
# DONE
# CLUSTERING AT THE INDIVIDUAL LEVEL
# Algorithm = kmeans
# K value(s) = 7
# Overwrite results = False
# K = 7
# ... Loading FC from file
# ... Running k-means clustering
#
#
# SUBJECT A039
# COMPUTE VOXELWISE FC
# Standardize = True
# Overwrite results = False
# ... Loading data
# ... Computing FC for all possibilities
# ... Metric: correlation
# ... Fisher transforming correlations
#
# DONE
# CLUSTERING AT THE INDIVIDUAL LEVEL
# Algorithm = kmeans
# K value(s) = 7
# Overwrite results = False
# K = 7
# ... Loading FC from file
# ... Running k-means clustering
#
#
# SUBJECT A043
# COMPUTE VOXELWISE FC
# Standardize = True
# Overwrite results = False
# ... Loading data
# ... Computing FC for all possibilities
# ... Metric: correlation
# ... Fisher transforming correlations
#
# DONE
# CLUSTERING AT THE INDIVIDUAL LEVEL
# Algorithm = kmeans
# K value(s) = 7
# Overwrite results = False
# K = 7
# ... Loading FC from file
# ... Running k-means clustering
#
#
# SUBJECT A044
# COMPUTE VOXELWISE FC
# Standardize = True
# Overwrite results = False
# ... Loading data
# ... Computing FC for all possibilities
# ... Metric: correlation
# ... Fisher transforming correlations
#
# DONE
# CLUSTERING AT THE INDIVIDUAL LEVEL
# Algorithm = kmeans
# K value(s) = 7
# Overwrite results = False
# K = 7
# ... Loading FC from file
# ... Running k-means clustering
#
#
# SUBJECT A045
# COMPUTE VOXELWISE FC
# Standardize = True
# Overwrite results = False
# ... Loading data
# ... Computing FC for all possibilities
# ... Metric: correlation
# ... Fisher transforming correlations
#
# DONE
# CLUSTERING AT THE INDIVIDUAL LEVEL
# Algorithm = kmeans
# K value(s) = 7
# Overwrite results = False
# K = 7
# ... Loading FC from file
# ... Running k-means clustering
#
#
# SUBJECT A046
# COMPUTE VOXELWISE FC
# Standardize = True
# Overwrite results = False
# ... Loading data
# ... Computing FC for all possibilities
# ... Metric: correlation
# ... Fisher transforming correlations
#
# DONE
# CLUSTERING AT THE INDIVIDUAL LEVEL
# Algorithm = kmeans
# K value(s) = 7
# Overwrite results = False
# K = 7
# ... Loading FC from file
# ... Running k-means clustering
#
#
# SUBJECT A048
# COMPUTE VOXELWISE FC
# Standardize = True
# Overwrite results = False
# ... Loading data
# ... Computing FC for all possibilities
# ... Metric: correlation
# ... Fisher transforming correlations
#
# DONE
# CLUSTERING AT THE INDIVIDUAL LEVEL
# Algorithm = kmeans
# K value(s) = 7
# Overwrite results = False
# K = 7
# ... Loading FC from file
# ... Running k-means clustering
#
#
# SUBJECT A050
# COMPUTE VOXELWISE FC
# Standardize = True
# Overwrite results = False
# ... Loading data
# ... Computing FC for all possibilities
# ... Metric: correlation
# ... Fisher transforming correlations
#
# DONE
# CLUSTERING AT THE INDIVIDUAL LEVEL
# Algorithm = kmeans
# K value(s) = 7
# Overwrite results = False
# K = 7
# ... Loading FC from file
# ... Running k-means clustering
#
#
# SUBJECT A051
# COMPUTE VOXELWISE FC
# Standardize = True
# Overwrite results = False
# ... Loading data
# ... Computing FC for all possibilities
# ... Metric: correlation
# ... Fisher transforming correlations
#
# DONE
# CLUSTERING AT THE INDIVIDUAL LEVEL
# Algorithm = kmeans
# K value(s) = 7
# Overwrite results = False
# K = 7
# ... Loading FC from file
# ... Running k-means clustering
#
#
# SUBJECT A052
# COMPUTE VOXELWISE FC
# Standardize = True
# Overwrite results = False
# ... Loading data
# ... Computing FC for all possibilities
# ... Metric: correlation
# ... Fisher transforming correlations
#
# DONE
# CLUSTERING AT THE INDIVIDUAL LEVEL
# Algorithm = kmeans
# K value(s) = 7
# Overwrite results = False
# K = 7
# ... Loading FC from file
# ... Running k-means clustering
#
#
# ... Operation performed in 123116.28 s!

# %% [markdown]
# ### Compute the group-level clustering and generate corresponding maps

# %%
fc_parcellation.group_clustering(k_range=[3,4,6],indiv_algorithm='kmeans',overwrite=False)
# Out:
# CLUSTERING AT THE GROUP LEVEL
# K value(s) = [3, 4, 6]
# Overwrite results = False
# WARNING: THESE RESULTS CHANGE IF GROUP CHANGES, MAKE SURE YOU ARE USING THE SAME SUBJECTS
#
# K = 3
# ... Group labeling already done!
# K = 4
# ... Group labeling already done!
# K = 6
# ... Group labeling already done!
#
# DONE

# %%
fc_parcellation.prepare_target_maps(label_type='indiv',indiv_algorithm='kmeans',k_range=[3,4,6],overwrite=False)
# Out:
# PREPARE TARGET MAPS
# Type of source labels = indiv
# K value(s) = [3, 4, 6]
# Overwrite results = False
# K = 3
# ... Computing target maps
# ...... Subject P030
# ...... Subject P099
# ...... Subject A006
# ...... Subject A007
# ...... Subject A008
# ...... Subject A009
# ...... Subject A011
# ...... Subject A013
# ...... Subject A023
# ...... Subject A024
# ...... Subject A025
# ...... Subject A026
# ...... Subject A027
# ...... Subject A028
# ...... Subject A029
# ...... Subject A030
# ...... Subject A032
# ...... Subject A033
# ...... Subject A034
# ...... Subject A036
# ...... Subject A037
# ...... Subject A038
# ...... Subject A039
# ...... Subject A043
# ...... Subject A044
# ...... Subject A045
# ...... Subject A046
# ...... Subject A048
# ...... Subject A050
# ...... Subject A051
# ...... Subject A052
# K = 4
# ... Computing target maps
# ...... Subject P030
# ...... Subject P099
# ...... Subject A006
# ...... Subject A007
# ...... Subject A008
# ...... Subject A009
# ...... Subject A011
# ...... Subject A013
# ...... Subject A023
# ...... Subject A024
# ...... Subject A025
# ...... Subject A026
# ...... Subject A027
# ...... Subject A028
# ...... Subject A029
# ...... Subject A030
# ...... Subject A032
# ...... Subject A033
# ...... Subject A034
# ...... Subject A036
# ...... Subject A037
# ...... Subject A038
# ...... Subject A039
# ...... Subject A043
# ...... Subject A044
# ...... Subject A045
# ...... Subject A046
# ...... Subject A048
# ...... Subject A050
# ...... Subject A051
# ...... Subject A052
# K = 6
# ... Computing target maps
# ...... Subject P030
# ...... Subject P099
# ...... Subject A006
# ...... Subject A007
# ...... Subject A008
# ...... Subject A009
# ...... Subject A011
# ...... Subject A013
# ...... Subject A023
# ...... Subject A024
# ...... Subject A025
# ...... Subject A026
# ...... Subject A027
# ...... Subject A028
# ...... Subject A029
# ...... Subject A030
# ...... Subject A032
# ...... Subject A033
# ...... Subject A034
# ...... Subject A036
# ...... Subject A037
# ...... Subject A038
# ...... Subject A039
# ...... Subject A043
# ...... Subject A044
# ...... Subject A045
# ...... Subject A046
# ...... Subject A048
# ...... Subject A050
# ...... Subject A051
# ...... Subject A052
# DONE

# %%
fc_parcellation.prepare_target_maps(label_type='group_mode',indiv_algorithm='kmeans',k_range=[3,4,6],overwrite=False)
# Out:
# PREPARE TARGET MAPS
# Type of source labels = group_mode
# K value(s) = [3, 4, 6]
# Overwrite results = False
# K = 3
# ... Computing target maps
# ...... Subject P030
# ...... Subject P099
# ...... Subject A006
# ...... Subject A007
# ...... Subject A008
# ...... Subject A009
# ...... Subject A011
# ...... Subject A013
# ...... Subject A023
# ...... Subject A024
# ...... Subject A025
# ...... Subject A026
# ...... Subject A027
# ...... Subject A028
# ...... Subject A029
# ...... Subject A030
# ...... Subject A032
# ...... Subject A033
# ...... Subject A034
# ...... Subject A036
# ...... Subject A037
# ...... Subject A038
# ...... Subject A039
# ...... Subject A043
# ...... Subject A044
# ...... Subject A045
# ...... Subject A046
# ...... Subject A048
# ...... Subject A050
# ...... Subject A051
# ...... Subject A052
# K = 4
# ... Computing target maps
# ...... Subject P030
# ...... Subject P099
# ...... Subject A006
# ...... Subject A007
# ...... Subject A008
# ...... Subject A009
# ...... Subject A011
# ...... Subject A013
# ...... Subject A023
# ...... Subject A024
# ...... Subject A025
# ...... Subject A026
# ...... Subject A027
# ...... Subject A028
# ...... Subject A029
# ...... Subject A030
# ...... Subject A032
# ...... Subject A033
# ...... Subject A034
# ...... Subject A036
# ...... Subject A037
# ...... Subject A038
# ...... Subject A039
# ...... Subject A043
# ...... Subject A044
# ...... Subject A045
# ...... Subject A046
# ...... Subject A048
# ...... Subject A050
# ...... Subject A051
# ...... Subject A052
# K = 6
# ... Computing target maps
# ...... Subject P030
# ...... Subject P099
# ...... Subject A006
# ...... Subject A007
# ...... Subject A008
# ...... Subject A009
# ...... Subject A011
# ...... Subject A013
# ...... Subject A023
# ...... Subject A024
# ...... Subject A025
# ...... Subject A026
# ...... Subject A027
# ...... Subject A028
# ...... Subject A029
# ...... Subject A030
# ...... Subject A032
# ...... Subject A033
# ...... Subject A034
# ...... Subject A036
# ...... Subject A037
# ...... Subject A038
# ...... Subject A039
# ...... Subject A043
# ...... Subject A044
# ...... Subject A045
# ...... Subject A046
# ...... Subject A048
# ...... Subject A050
# ...... Subject A051
# ...... Subject A052
# DONE

# %% [markdown]
# ### Statistics and WTA analysis

# %%
fc_parcellation.stats_target_maps(label_type='group_mode',indiv_algorithm='kmeans',k_range=3,overwrite=False)
# Out:
# RUN STATISTICAL ANALYSIS
# Type of source labels = group_mode
# K value(s) = 3
# Overwrite results = False
# K = 3
# ... Merging target files
# fslmerge -t /media/miplab-nas2/Data3/BMPD/hc_project//brain_spine/results/fc_parcellation//corr/C1toC7_gm_V_to_wholebrain/target//K3/group_mode_labels/maps_indiv/C1toC7_gm_V_to_wholebrain_all_kmeans_group_mode_labels_targetmap_K3_1.nii.gz /media/miplab-nas2/Data3/BMPD/hc_project//brain_spine/results/fc_parcellation//corr/C1toC7_gm_V_to_wholebrain/target//K3/group_mode_labels/maps_indiv/C1toC7_gm_V_to_wholebrain_*_kmeans_group_mode_labels_targetmap_K3_1.nii.gz
# ... Running statistical analysis
# randomise options: -i /media/miplab-nas2/Data3/BMPD/hc_project//brain_spine/results/fc_parcellation//corr/C1toC7_gm_V_to_wholebrain/target//K3/group_mode_labels/maps_indiv/C1toC7_gm_V_to_wholebrain_all_kmeans_group_mode_labels_targetmap_K3_1.nii.gz -m /media/miplab-nas2/Data3/BMPD/hc_project//analysis/masks/brain_old_3mm/MNI_GM_3mm.nii.gz -o /media/miplab-nas2/Data3/BMPD/hc_project//brain_spine/results/fc_parcellation//corr/C1toC7_gm_V_to_wholebrain/target//K3/group_mode_labels/stats/kmeans/K3_1 -1
# Loading Data:
# Data loaded
# One-sample design detected; sign-flipping instead of permuting.
# 2.14748e+09 sign-flips required for exhaustive test of t-test 1
# Doing 5000 random permutations
# Warning! No output options selected. Outputing raw tstat only
# Starting permutation 1 (Unpermuted data)
# Finished, exiting.
# ... Merging target files
# fslmerge -t /media/miplab-nas2/Data3/BMPD/hc_project//brain_spine/results/fc_parcellation//corr/C1toC7_gm_V_to_wholebrain/target//K3/group_mode_labels/maps_indiv/C1toC7_gm_V_to_wholebrain_all_kmeans_group_mode_labels_targetmap_K3_2.nii.gz /media/miplab-nas2/Data3/BMPD/hc_project//brain_spine/results/fc_parcellation//corr/C1toC7_gm_V_to_wholebrain/target//K3/group_mode_labels/maps_indiv/C1toC7_gm_V_to_wholebrain_*_kmeans_group_mode_labels_targetmap_K3_2.nii.gz
# ... Running statistical analysis
# randomise options: -i /media/miplab-nas2/Data3/BMPD/hc_project//brain_spine/results/fc_parcellation//corr/C1toC7_gm_V_to_wholebrain/target//K3/group_mode_labels/maps_indiv/C1toC7_gm_V_to_wholebrain_all_kmeans_group_mode_labels_targetmap_K3_2.nii.gz -m /media/miplab-nas2/Data3/BMPD/hc_project//analysis/masks/brain_old_3mm/MNI_GM_3mm.nii.gz -o /media/miplab-nas2/Data3/BMPD/hc_project//brain_spine/results/fc_parcellation//corr/C1toC7_gm_V_to_wholebrain/target//K3/group_mode_labels/stats/kmeans/K3_2 -1
# Loading Data:
# Data loaded
# One-sample design detected; sign-flipping instead of permuting.
# 2.14748e+09 sign-flips required for exhaustive test of t-test 1
# Doing 5000 random permutations
# Warning! No output options selected. Outputing raw tstat only
# Starting permutation 1 (Unpermuted data)
# Finished, exiting.
# ... Merging target files
# fslmerge -t /media/miplab-nas2/Data3/BMPD/hc_project//brain_spine/results/fc_parcellation//corr/C1toC7_gm_V_to_wholebrain/target//K3/group_mode_labels/maps_indiv/C1toC7_gm_V_to_wholebrain_all_kmeans_group_mode_labels_targetmap_K3_3.nii.gz /media/miplab-nas2/Data3/BMPD/hc_project//brain_spine/results/fc_parcellation//corr/C1toC7_gm_V_to_wholebrain/target//K3/group_mode_labels/maps_indiv/C1toC7_gm_V_to_wholebrain_*_kmeans_group_mode_labels_targetmap_K3_3.nii.gz
# ... Running statistical analysis
# randomise options: -i /media/miplab-nas2/Data3/BMPD/hc_project//brain_spine/results/fc_parcellation//corr/C1toC7_gm_V_to_wholebrain/target//K3/group_mode_labels/maps_indiv/C1toC7_gm_V_to_wholebrain_all_kmeans_group_mode_labels_targetmap_K3_3.nii.gz -m /media/miplab-nas2/Data3/BMPD/hc_project//analysis/masks/brain_old_3mm/MNI_GM_3mm.nii.gz -o /media/miplab-nas2/Data3/BMPD/hc_project//brain_spine/results/fc_parcellation//corr/C1toC7_gm_V_to_wholebrain/target//K3/group_mode_labels/stats/kmeans/K3_3 -1
# Loading Data:
# Data loaded
# One-sample design detected; sign-flipping instead of permuting.
# 2.14748e+09 sign-flips required for exhaustive test of t-test 1
# Doing 5000 random permutations
# Warning! No output options selected. Outputing raw tstat only
# Starting permutation 1 (Unpermuted data)
# Finished, exiting.
# DONE

# %%
fc_parcellation.winner_takes_all(label_type='group_mode',indiv_algorithm='kmeans',apply_threshold=1, k=3, order=[3,2,1], overwrite=False)
# Out:
# RUN WINNER-TAKES-ALL ANALYSIS
# Type of source labels = group_mode
# K value = 3
# Overwrite results = False
# K1 will have a value of 3
# K2 will have a value of 2
# K3 will have a value of 1
# DONE

# %% [markdown]
# # Plotting
# <hr style="border:0.5px solid black">

# %% [markdown]
# ### WTA maps

# %%
# Retrieve destrieux parcellation in fsaverage5 space from nilearn
from nilearn import datasets

destrieux_atlas = datasets.fetch_atlas_surf_destrieux()

# The parcellation is already loaded into memory
parcellation = destrieux_atlas['map_left']
# Out:
# Dataset created in /home/kinany/nilearn_data/destrieux_surface
#
# Downloading data from https://www.nitrc.org/frs/download.php/9343/lh.aparc.a2009s.annot ...
#  ...done. (1 seconds, 0 min)
# Downloading data from https://www.nitrc.org/frs/download.php/9342/rh.aparc.a2009s.annot ...
#  ...done. (1 seconds, 0 min)

# %%
type(parcellation)
# Out:
# numpy.ndarray

# %%
fc_parcellation.plot_brain_map(showing='target',label_type='indiv',indiv_algorithm='kmeans', k=3, save_figure=True)
# Out:
# RUN PLOTTING BRAIN MAPS
# K value = 3
# Showing = target
# Save figure = True
# 10242
# 271633
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 fc_parcellation.plot_brain_map(showing='target',label_type='indiv',indiv_algorithm='kmeans', k=3, save_figure=True)
#
# File /media/miplab-nas2/Data3/BMPD/hc_project/analysis/code/fc_based_parcellation.py:782, in FC_Parcellation.plot_brain_map(self, k, indiv_algorithm, showing, colormap, label_type, poscorr, save_figure)
#     775 print(image_array.size)
#     776 for hemi in ['left','right']:
#     777     #big_texture = surface.vol_to_surf(img_to_show, big_fsaverage.pial_right) if hemi == 'right' else surface.vol_to_surf(img_to_show, big_fsaverage.pial_left)
#     778     #plot = plotting.plot_surf(big_fsaverage.infl_right if hemi == 'right' else big_fsaverage.infl_left,
#     779      #                               big_texture, hemi=hemi, colorbar=True,
#     780       #                              vmin=1, vmax=k, cmap=discretized_colormap,
#     781        #                             bg_map=big_fsaverage.sulc_right if hemi == 'right' else big_fsaverage.sulc_left )
# --> 782     plot = plotting.plot_surf_roi(big_fsaverage['infl_left'], roi_map=image_array.ravel(),
#     783                hemi='left', view='lateral',
#     784                bg_map=big_fsaverage['sulc_left'], bg_on_data=True,
#     785                darkness=.5)
#     787     #plotting.plot_roi(big_fsaverage.infl_right if hemi == 'right' else big_fsaverage.infl_left,
#     788      #                               roi_map=parcellation, hemi=hemi, colorbar=True,
#     789       #                              vmin=1, vmax=k, cmap=discretized_colormap,
#     790        #                             bg_map=big_fsaverage['sulc_right'] if hemi == 'right' else big_fsaverage['sulc_left'])
#     791     # If option is set, save results as a png
#     792     if save_figure == True:
#
# File ~/anaconda3/lib/python3.9/site-packages/nilearn/plotting/surf_plotting.py:1649, in plot_surf_roi(surf_mesh, roi_map, bg_map, hemi, view, engine, avg_method, threshold, alpha, vmin, vmax, cmap, cbar_tick_format, bg_on_data, darkness, title, title_font_size, output_file, axes, figure, **kwargs)
#    1646     raise ValueError('roi_map can only have one dimension but has '
#    1647                      f'{roi.ndim} dimensions')
#    1648 if roi.shape[0] != mesh[0].shape[0]:
# -> 1649     raise ValueError('roi_map does not have the same number of vertices '
#    1650                      'as the mesh. If you have a list of indices for the '
#    1651                      'ROI you can convert them into a ROI map like this:\n'
#    1652                      'roi_map = np.zeros(n_vertices)\n'
#    1653                      'roi_map[roi_idx] = 1')
#    1655 if cbar_tick_format == "auto":
#    1656     cbar_tick_format = "." if engine == "plotly" else "%i"
#
# ValueError: roi_map does not have the same number of vertices as the mesh. If you have a list of indices for the ROI you can convert them into a ROI map like this:
# roi_map = np.zeros(n_vertices)
# roi_map[roi_idx] = 1

# %% [markdown]
# ### Plot label maps

# %%
fc_parcellation.plot_spinal_map(showing='source',indiv_algorithm='kmeans', k=4, order=[3,2,4,1], save_figure=True)
# Out:
# RUN PLOTTING SPINAL MAPS
# K value = 3
# Showing = source
# Save figure = True
# The plotting is displayed in neurological orientation (Left > Right)

# %% [markdown]
# # Validity
# <hr style="border:0.5px solid black">

# %% [markdown]
# ### Plot validity metrics

# %%
fc_parcellation.plot_validity(k_range=range(3,9),internal=["SSE", "silhouette", "davies", "calinski"], group=["ami_mode", "ari_mode","ami_agglom", "ari_agglom", "corr"], save_figures=True)
# Out:
# VALIDITY METRICS
# K value(s) = range(3, 9)
# Saving figures = True
