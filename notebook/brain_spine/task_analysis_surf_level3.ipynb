# %% [markdown]
# # <font color=black> Analysis - Task-based analyses - 3rd level </font>
# <hr style="border:1px solid black">

# %%
import sys,json
import glob, os
import numpy as np
import nibabel as nib
import matplotlib.pyplot as plt
import pandas as pd

sys.path.append('/media/miplab-nas2/Data3/BMPD/hc_project/analysis/code/')

from task_analyses_surf_paper import TaskAnalysis

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Initialization
# <hr style="border:0.5px solid black">

# %%
# Load the config file with all information
with open('../../config/config_task_analyses.json') as config_file:
    config = json.load(config_file)
task_analysis = TaskAnalysis(config)

# %% [markdown]
# # Analyses
# <hr style="border:0.5px solid black">

# %% [markdown]
# ### Computing 3rd level statistics

# %%
task_analysis.run_level3()
# Out:
# RUNNING 3RD LEVEL ANALYSIS
# ... Movement: Jaw
# ... Movement: Upperarm
# ... Movement: Forearm
# ... Movement: Wrist
# ... Movement: Finger
# DONE

# %% [markdown]
# ### Plotting maps & outlines

# %%
task_analysis.plot_results()
# Out:
# PLOTTING RESULTS
# ... Movement: Jaw
# ... Movement: Upperarm
# ... Movement: Forearm
# ... Movement: Wrist
# ... Movement: Finger

# %%
task_analysis.plot_outlines()
# Out:
# PLOTTING OUTLINES
# ... Movement: Jaw
# ... Movement: Upperarm
# ... Movement: Forearm
# ... Movement: Wrist
# ... Movement: Finger

# %% [markdown]
# ### Winner-take-all analyse

# %%
task_analysis.winner_takes_all()
# Out:
# RUN WINNER-TAKES-ALL ANALYSIS
# ... Hemisphere: left
# ... Computing WTA
# ... Saving
# ... Hemisphere: right
# ... Computing WTA
# ... Saving
# DONE

# %%
df = pd.read_csv('/media/miplab-nas2/Data3/Somato/participants.tsv', sep='\t')

# %%
# Compute the mean and standard deviation of the "age" column
age_mean = df['age'].mean()
age_std = df['age'].std()

# Count the occurrences of each value in the "sex" column
sex_counts = df['sex'].value_counts()

# Print the results
print("Mean age:", age_mean)
print("Standard deviation of age:", age_std)
print("Counts of sex values:")
print(sex_counts)

# %%
task_analysis.winner_takes_all(movements=['Jaw','Upperarm','Forearm','Wrist','Finger'])
