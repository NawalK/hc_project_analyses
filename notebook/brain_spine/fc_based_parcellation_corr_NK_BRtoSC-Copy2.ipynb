# %% [markdown]
# # <font color=black> Analysis - FC-based parcellation using correlation </font>
# <hr style="border:1px solid black">

# %%
import sys,json
import glob, os
import numpy as np
import nibabel as nib
import time

sys.path.append('/media/miplab-nas2/Data3/BMPD/hc_project/analysis/code/')

from fc_based_parcellation import FC_Parcellation

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Initialization
# <hr style="border:0.5px solid black">

# %% [markdown]
# ### Load configuration file

# %%
# Load the config file with all information
with open('../../config/config_fc_based_parcellation_NK.json') as config_file:
    config = json.load(config_file)

# %% [markdown]
# ### Set relevant parameters

# %%
# Define tag of this analysis (used for saving)
config['output_tag'] = "C1toC6_gm_to_prepostcentral"
# Define source, target, and the corresponding masks
source = 'spinalcord'
target = 'brain'
# Note: paths should be with respect to main directory
config['file_tag']['brain'] = "_task-rest_bold_stc_brain_moco_brsc_BP_reg_SPM_inTemplate_s.nii.gz"
config['file_tag']['spinalcord'] = "_task-rest_bold_stc_sc_moco_brsc_BP_inTemplate_s.nii.gz"

config['masks']['brain'] = "/analysis/mask/brain/julich_pre_and_postcentral.nii.gz"
config['masks']['spinalcord'] = "/analysis/mask/spinalcord/full/gm/C1C6_gm.nii.gz"
config['list_subjects'] = ["P030", "P099","A006","A007","A008","A009","A011","A013","A023","A024","A025","A026","A027","A028","A029","A030","A032","A033","A034","A036","A037","A038","A039","A043","A044","A045","A046","A048","A050","A051","A052"]

# %% [markdown]
# ### Instantiate class
# _Note: this will save a config file with all relevant information and prepare folder structure_

# %%
fc_parcellation = FC_Parcellation(config,source,target,'corr')

# %% [markdown]
# # Analyses
# <hr style="border:0.5px solid black">

# %% [markdown]
# ### Compute the voxelwise correlation & run clustering for each subject independently

# %%
start = time.time()
# Loop through the subjects to compute fc and clustering 
for sub_id,sub in enumerate(fc_parcellation.config['list_subjects']): 
    print(f'\033[1mSUBJECT {sub}\033[0m')
    # Compute correlation without saving files
    fc_parcellation.compute_voxelwise_fc(sub=sub, 
                                        overwrite=False)
    # Run clustering and save labels
    fc_parcellation.run_clustering(sub=sub,
                                    k_range=6,algorithm='kmeans',
                                    overwrite=False)
print("\033[1m... Operation performed in %.2f s!\033[0m" % (time.time() - start))
# Out:
# SUBJECT P030
# COMPUTE VOXELWISE FC
# Standardize = True
# Overwrite results = False
# ... FC already computed
#
# DONE
# CLUSTERING AT THE INDIVIDUAL LEVEL
# Algorithm = kmeans
# K value(s) = 6
# Overwrite results = False
# K = 6
# ... Loading FC from file
# ... Running k-means clustering
#
#
# SUBJECT P099
# COMPUTE VOXELWISE FC
# Standardize = True
# Overwrite results = False
# ... Loading data
# ... Computing FC for all possibilities
# ... Metric: correlation
# ... Fisher transforming correlations
#
# DONE
# CLUSTERING AT THE INDIVIDUAL LEVEL
# Algorithm = kmeans
# K value(s) = 6
# Overwrite results = False
# K = 6
# ... Loading FC from file
# ... Running k-means clustering
#
#
# SUBJECT A006
# COMPUTE VOXELWISE FC
# Standardize = True
# Overwrite results = False
# ... Loading data
# ... Computing FC for all possibilities
# ... Metric: correlation
# ... Fisher transforming correlations
#
# DONE
# CLUSTERING AT THE INDIVIDUAL LEVEL
# Algorithm = kmeans
# K value(s) = 6
# Overwrite results = False
# K = 6
# ... Loading FC from file
# ... Running k-means clustering
#
#
# SUBJECT A007
# COMPUTE VOXELWISE FC
# Standardize = True
# Overwrite results = False
# ... Loading data
# ... Computing FC for all possibilities
# ... Metric: correlation
# ... Fisher transforming correlations
#
# DONE
# CLUSTERING AT THE INDIVIDUAL LEVEL
# Algorithm = kmeans
# K value(s) = 6
# Overwrite results = False
# K = 6
# ... Loading FC from file
# ... Running k-means clustering
#
#
# SUBJECT A008
# COMPUTE VOXELWISE FC
# Standardize = True
# Overwrite results = False
# ... Loading data
# ... Computing FC for all possibilities
# ... Metric: correlation
# ... Fisher transforming correlations
#
# DONE
# CLUSTERING AT THE INDIVIDUAL LEVEL
# Algorithm = kmeans
# K value(s) = 6
# Overwrite results = False
# K = 6
# ... Loading FC from file
# ... Running k-means clustering
#
#
# SUBJECT A009
# COMPUTE VOXELWISE FC
# Standardize = True
# Overwrite results = False
# ... Loading data
# ... Computing FC for all possibilities
# ... Metric: correlation
# ... Fisher transforming correlations
#
# DONE
# CLUSTERING AT THE INDIVIDUAL LEVEL
# Algorithm = kmeans
# K value(s) = 6
# Overwrite results = False
# K = 6
# ... Loading FC from file
# ... Running k-means clustering
#
#
# SUBJECT A011
# COMPUTE VOXELWISE FC
# Standardize = True
# Overwrite results = False
# ... Loading data
# ... Computing FC for all possibilities
# ... Metric: correlation
# ... Fisher transforming correlations
#
# DONE
# CLUSTERING AT THE INDIVIDUAL LEVEL
# Algorithm = kmeans
# K value(s) = 6
# Overwrite results = False
# K = 6
# ... Loading FC from file
# ... Running k-means clustering
#
#
# SUBJECT A013
# COMPUTE VOXELWISE FC
# Standardize = True
# Overwrite results = False
# ... Loading data
# ... Computing FC for all possibilities
# ... Metric: correlation
# ... Fisher transforming correlations
#
# DONE
# CLUSTERING AT THE INDIVIDUAL LEVEL
# Algorithm = kmeans
# K value(s) = 6
# Overwrite results = False
# K = 6
# ... Loading FC from file
# ... Running k-means clustering
#
#
# SUBJECT A023
# COMPUTE VOXELWISE FC
# Standardize = True
# Overwrite results = False
# ... Loading data
# ... Computing FC for all possibilities
# ... Metric: correlation
# ... Fisher transforming correlations
#
# DONE
# CLUSTERING AT THE INDIVIDUAL LEVEL
# Algorithm = kmeans
# K value(s) = 6
# Overwrite results = False
# K = 6
# ... Loading FC from file
# ... Running k-means clustering
#
#
# SUBJECT A024
# COMPUTE VOXELWISE FC
# Standardize = True
# Overwrite results = False
# ... Loading data
# ... Computing FC for all possibilities
# ... Metric: correlation
# ... Fisher transforming correlations
#
# DONE
# CLUSTERING AT THE INDIVIDUAL LEVEL
# Algorithm = kmeans
# K value(s) = 6
# Overwrite results = False
# K = 6
# ... Loading FC from file
# ... Running k-means clustering
#
#
# SUBJECT A025
# COMPUTE VOXELWISE FC
# Standardize = True
# Overwrite results = False
# ... Loading data
# ... Computing FC for all possibilities
# ... Metric: correlation
# ... Fisher transforming correlations
#
# DONE
# CLUSTERING AT THE INDIVIDUAL LEVEL
# Algorithm = kmeans
# K value(s) = 6
# Overwrite results = False
# K = 6
# ... Loading FC from file
# ... Running k-means clustering
#
#
# SUBJECT A026
# COMPUTE VOXELWISE FC
# Standardize = True
# Overwrite results = False
# ... Loading data
# ... Computing FC for all possibilities
# ... Metric: correlation
# ... Fisher transforming correlations
#
# DONE
# CLUSTERING AT THE INDIVIDUAL LEVEL
# Algorithm = kmeans
# K value(s) = 6
# Overwrite results = False
# K = 6
# ... Loading FC from file
# ... Running k-means clustering
#
#
# SUBJECT A027
# COMPUTE VOXELWISE FC
# Standardize = True
# Overwrite results = False
# ... Loading data
# ... Computing FC for all possibilities
# ... Metric: correlation
# ... Fisher transforming correlations
#
# DONE
# CLUSTERING AT THE INDIVIDUAL LEVEL
# Algorithm = kmeans
# K value(s) = 6
# Overwrite results = False
# K = 6
# ... Loading FC from file
# ... Running k-means clustering
#
#
# SUBJECT A028
# COMPUTE VOXELWISE FC
# Standardize = True
# Overwrite results = False
# ... Loading data
# ... Computing FC for all possibilities
# ... Metric: correlation
# ... Fisher transforming correlations
#
# DONE
# CLUSTERING AT THE INDIVIDUAL LEVEL
# Algorithm = kmeans
# K value(s) = 6
# Overwrite results = False
# K = 6
# ... Loading FC from file
# ... Running k-means clustering
#
#
# SUBJECT A029
# COMPUTE VOXELWISE FC
# Standardize = True
# Overwrite results = False
# ... Loading data
# ... Computing FC for all possibilities
# ... Metric: correlation
# ... Fisher transforming correlations
#
# DONE
# CLUSTERING AT THE INDIVIDUAL LEVEL
# Algorithm = kmeans
# K value(s) = 6
# Overwrite results = False
# K = 6
# ... Loading FC from file
# ... Running k-means clustering
#
#
# SUBJECT A030
# COMPUTE VOXELWISE FC
# Standardize = True
# Overwrite results = False
# ... Loading data
# ... Computing FC for all possibilities
# ... Metric: correlation
# ... Fisher transforming correlations
#
# DONE
# CLUSTERING AT THE INDIVIDUAL LEVEL
# Algorithm = kmeans
# K value(s) = 6
# Overwrite results = False
# K = 6
# ... Loading FC from file
# ... Running k-means clustering
#
#
# SUBJECT A032
# COMPUTE VOXELWISE FC
# Standardize = True
# Overwrite results = False
# ... Loading data
# ... Computing FC for all possibilities
# ... Metric: correlation
# ... Fisher transforming correlations
#
# DONE
# CLUSTERING AT THE INDIVIDUAL LEVEL
# Algorithm = kmeans
# K value(s) = 6
# Overwrite results = False
# K = 6
# ... Loading FC from file
# ... Running k-means clustering
#
#
# SUBJECT A033
# COMPUTE VOXELWISE FC
# Standardize = True
# Overwrite results = False
# ... Loading data
# ... Computing FC for all possibilities
# ... Metric: correlation
# ... Fisher transforming correlations
#
# DONE
# CLUSTERING AT THE INDIVIDUAL LEVEL
# Algorithm = kmeans
# K value(s) = 6
# Overwrite results = False
# K = 6
# ... Loading FC from file
# ... Running k-means clustering
#
#
# SUBJECT A034
# COMPUTE VOXELWISE FC
# Standardize = True
# Overwrite results = False
# ... Loading data
# ... Computing FC for all possibilities
# ... Metric: correlation
# ... Fisher transforming correlations
#
# DONE
# CLUSTERING AT THE INDIVIDUAL LEVEL
# Algorithm = kmeans
# K value(s) = 6
# Overwrite results = False
# K = 6
# ... Loading FC from file
# ... Running k-means clustering
# SUBJECT A036
# COMPUTE VOXELWISE FC
# Standardize = True
# Overwrite results = False
# ... Loading data
# ... Computing FC for all possibilities
# ... Metric: correlation
# ... Fisher transforming correlations
#
# DONE
# CLUSTERING AT THE INDIVIDUAL LEVEL
# Algorithm = kmeans
# K value(s) = 6
# Overwrite results = False
# K = 6
# ... Loading FC from file
# ... Running k-means clustering
#
#
# SUBJECT A037
# COMPUTE VOXELWISE FC
# Standardize = True
# Overwrite results = False
# ... Loading data
# ... Computing FC for all possibilities
# ... Metric: correlation
# ... Fisher transforming correlations
#
# DONE
# CLUSTERING AT THE INDIVIDUAL LEVEL
# Algorithm = kmeans
# K value(s) = 6
# Overwrite results = False
# K = 6
# ... Loading FC from file
# ... Running k-means clustering
#
#
# SUBJECT A038
# COMPUTE VOXELWISE FC
# Standardize = True
# Overwrite results = False
# ... Loading data
# ... Computing FC for all possibilities
# ... Metric: correlation
# ... Fisher transforming correlations
#
# DONE
# CLUSTERING AT THE INDIVIDUAL LEVEL
# Algorithm = kmeans
# K value(s) = 6
# Overwrite results = False
# K = 6
# ... Loading FC from file
# ... Running k-means clustering
#
#
# SUBJECT A039
# COMPUTE VOXELWISE FC
# Standardize = True
# Overwrite results = False
# ... Loading data
# ... Computing FC for all possibilities
# ... Metric: correlation
# ... Fisher transforming correlations
#
# DONE
# CLUSTERING AT THE INDIVIDUAL LEVEL
# Algorithm = kmeans
# K value(s) = 6
# Overwrite results = False
# K = 6
# ... Loading FC from file
# ... Running k-means clustering
#
#
# SUBJECT A043
# COMPUTE VOXELWISE FC
# Standardize = True
# Overwrite results = False
# ... Loading data
# ... Computing FC for all possibilities
# ... Metric: correlation
# ... Fisher transforming correlations
#
# DONE
# CLUSTERING AT THE INDIVIDUAL LEVEL
# Algorithm = kmeans
# K value(s) = 6
# Overwrite results = False
# K = 6
# ... Loading FC from file
# ... Running k-means clustering
#
#
# SUBJECT A044
# COMPUTE VOXELWISE FC
# Standardize = True
# Overwrite results = False
# ... Loading data
# ... Computing FC for all possibilities
# ... Metric: correlation
# ... Fisher transforming correlations
#
# DONE
# CLUSTERING AT THE INDIVIDUAL LEVEL
# Algorithm = kmeans
# K value(s) = 6
# Overwrite results = False
# K = 6
# ... Loading FC from file
# ... Running k-means clustering
#
#
# SUBJECT A045
# COMPUTE VOXELWISE FC
# Standardize = True
# Overwrite results = False
# ... Loading data
# ... Computing FC for all possibilities
# ... Metric: correlation
# ... Fisher transforming correlations
#
# DONE
# CLUSTERING AT THE INDIVIDUAL LEVEL
# Algorithm = kmeans
# K value(s) = 6
# Overwrite results = False
# K = 6
# ... Loading FC from file
# ... Running k-means clustering
#
#
# SUBJECT A046
# COMPUTE VOXELWISE FC
# Standardize = True
# Overwrite results = False
# ... Loading data
# ... Computing FC for all possibilities
# ... Metric: correlation
# ... Fisher transforming correlations
#
# DONE
# CLUSTERING AT THE INDIVIDUAL LEVEL
# Algorithm = kmeans
# K value(s) = 6
# Overwrite results = False
# K = 6
# ... Loading FC from file
# ... Running k-means clustering
#
#
# SUBJECT A048
# COMPUTE VOXELWISE FC
# Standardize = True
# Overwrite results = False
# ... Loading data
# ... Computing FC for all possibilities
# ... Metric: correlation
# ... Fisher transforming correlations
#
# DONE
# CLUSTERING AT THE INDIVIDUAL LEVEL
# Algorithm = kmeans
# K value(s) = 6
# Overwrite results = False
# K = 6
# ... Loading FC from file
# ... Running k-means clustering
#
#
# SUBJECT A050
# COMPUTE VOXELWISE FC
# Standardize = True
# Overwrite results = False
# ... Loading data
# ... Computing FC for all possibilities
# ... Metric: correlation
# ... Fisher transforming correlations
#
# DONE
# CLUSTERING AT THE INDIVIDUAL LEVEL
# Algorithm = kmeans
# K value(s) = 6
# Overwrite results = False
# K = 6
# ... Loading FC from file
# ... Running k-means clustering
#
#
# SUBJECT A051
# COMPUTE VOXELWISE FC
# Standardize = True
# Overwrite results = False
# ... Loading data
# ... Computing FC for all possibilities
# ... Metric: correlation
# ... Fisher transforming correlations
#
# DONE
# CLUSTERING AT THE INDIVIDUAL LEVEL
# Algorithm = kmeans
# K value(s) = 6
# Overwrite results = False
# K = 6
# ... Loading FC from file
# ... Running k-means clustering
#
#
# SUBJECT A052
# COMPUTE VOXELWISE FC
# Standardize = True
# Overwrite results = False
# ... Loading data
# ... Computing FC for all possibilities
# ... Metric: correlation
# ... Fisher transforming correlations
#
# DONE
# CLUSTERING AT THE INDIVIDUAL LEVEL
# Algorithm = kmeans
# K value(s) = 6
# Overwrite results = False
# K = 6
# ... Loading FC from file
# ... Running k-means clustering
#
#
# ... Operation performed in 3848.12 s!

# %% [markdown]
# ### Compute the group-level clustering and generate corresponding maps

# %%
fc_parcellation.group_clustering(k_range=6,indiv_algorithm='kmeans',overwrite=False)
# Out:
# CLUSTERING AT THE GROUP LEVEL
# K value(s) = 6
# Overwrite results = False
# WARNING: THESE RESULTS CHANGE IF GROUP CHANGES, MAKE SURE YOU ARE USING THE SAME SUBJECTS
#
# K = 6
# ... Computing hierarchical clustering and relabeling
# ...... Loading all subjects
# ...... Clustering on all labels
# ...... Computing cophenetic correlation
# ...... Relabeling
# ...... Computing validity
#
# DONE

# %%
fc_parcellation.prepare_target_maps(label_type='indiv',indiv_algorithm='kmeans',k_range=6,overwrite=False)
# Out:
# PREPARE TARGET MAPS
# Type of source labels = indiv
# K value(s) = 6
# Overwrite results = False
# K = 6
# ... Computing target maps
# ...... Subject P030
# ...... Subject P099
# ...... Subject A006
# ...... Subject A007
# ...... Subject A008
# ...... Subject A009
# ...... Subject A011
# ...... Subject A013
# ...... Subject A023
# ...... Subject A024
# ...... Subject A025
# ...... Subject A026
# ...... Subject A027
# ...... Subject A028
# ...... Subject A029
# ...... Subject A030
# ...... Subject A032
# ...... Subject A033
# ...... Subject A034
# ...... Subject A036
# ...... Subject A037
# ...... Subject A038
# ...... Subject A039
# ...... Subject A043
# ...... Subject A044
# ...... Subject A045
# ...... Subject A046
# ...... Subject A048
# ...... Subject A050
# ...... Subject A051
# ...... Subject A052
# DONE

# %% [markdown]
# ### Plot validity metrics

# %%
fc_parcellation.plot_validity(k_range=range(5,15),internal=["SSE", "silhouette", "davies", "calinski"], group=["ami", "ari", "corr"], save_figures=False)
# Out:
# VALIDITY METRICS
# K value(s) = range(5, 15)
# Saving figures = False
