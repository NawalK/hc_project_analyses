# %% [markdown]
# ## <font color=#B2D732> <span style="background-color: #4424D6"> Imports

# %%
import sys,json
import glob, os
from nilearn import plotting, datasets     

sys.path.append('/media/miplab-nas2/Data3/BMPD/hc_project/analysis/code/')

from stats_group_level_NK import Stats

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## <font color=#B2D732> <span style="background-color: #4424D6"> A/ Initialization

# %% [markdown]
#  ### <font color=#4424D6> I. Configuration & parameters </font >

# %%
# Load config file ------------------------------------------------------------
with open('../../config/config_seed2voxels_2ndlevel_NK.json') as config_file: # the notebook should be in 'xx/notebook/' folder #config_proprio
    config = json.load(config_file) # load config file should be open first and the path inside modified
    
#ana2run=["frost_C1_gm","frost_C2_gm","frost_C3_gm","frost_C4_gm","frost_C5_gm","frost_C6_gm","frost_C7_gm"] # copy and pass the analyse name (same as config["seeds"])
#ana2run=["frost_C1_gmwm","frost_C2_gmwm","frost_C3_gmwm","frost_C4_gmwm","frost_C5_gmwm","frost_C6_gmwm","frost_C7_gmwm"] # copy and pass the analyse name (same as config["seeds"])
ana2run=["icap_C1","icap_C2","icap_C3","icap_C4","icap_C5","icap_C6","icap_C7"] # copy and pass the analyse name (same as config["seeds"])
#ana2run=["frost_C1_R_gmwm","frost_C2_R_gmwm","frost_C3_R_gmwm","frost_C4_R_gmwm","frost_C5_R_gmwm","frost_C6_R_gmwm","frost_C7_R_gmwm"] # copy and pass the analyse name (same as config["seeds"])
#ana2run = ["icap_C1_LminR","icap_C2_LminR","icap_C3_LminR","icap_C4_LminR"]
#ana2run = ["icap_C1_DminV","icap_C2_DminV","icap_C3_DminV","icap_C4_DminV","icap_C5_DminV","icap_C6_DminV","icap_C7_DminV"]
#ana2run = ["icap_C1_V","icap_C2_V","icap_C3_V","icap_C4_V","icap_C5_V","icap_C6_V","icap_C7_V"]

#ana2run = ["C1C7_DR_min_DL_gm","C1C7_VR_min_VL_gm","C1C7_DR_min_VR_gm","C1C7_DL_min_VL_gm"]
#ana2run = ["C17_D_gm","C1C7_V_gm","C1C7_R_gm","C1C7_L_gm"]
#ana2run = ["C1C7_D_gm_min_C1C7_V_gm","C1C7_L_gm_min_C1C7_R_gm"]
#The model should be defined in the config file line 5 : "OneSampleT" "TwoSampT_paired" "TwoSampT_unpaired" 'HigherOrder_paired'

# %% [markdown]
# ### <font color=#4424D6> II. Initialize class based on this </font>

# %%
stats={}
for ana_name in ana2run:
    stats[ana_name]=Stats(config,ana_name,save_ana=True) # initialize the function
# Out:
# **************************************
# Initiate icap_C1 analysis
#
# > Statistical model: OneSampleT
# > Number of participants: 31
# > Mask : MNI_GM_3mm_SMC.nii
# > Saved here : /media/miplab-nas2/Data3/BMPD/hc_project//brain_spine/results/seed_to_voxels//2_second_level/OneSampleT/MNI_GM_3mm_SMC/MI/icap_C1
#
# **************************************
# Initiate icap_C2 analysis
#
# > Statistical model: OneSampleT
# > Number of participants: 31
# > Mask : MNI_GM_3mm_SMC.nii
# > Saved here : /media/miplab-nas2/Data3/BMPD/hc_project//brain_spine/results/seed_to_voxels//2_second_level/OneSampleT/MNI_GM_3mm_SMC/MI/icap_C2
#
# **************************************
# Initiate icap_C3 analysis
#
# > Statistical model: OneSampleT
# > Number of participants: 31
# > Mask : MNI_GM_3mm_SMC.nii
# > Saved here : /media/miplab-nas2/Data3/BMPD/hc_project//brain_spine/results/seed_to_voxels//2_second_level/OneSampleT/MNI_GM_3mm_SMC/MI/icap_C3
#
# **************************************
# Initiate icap_C4 analysis
#
# > Statistical model: OneSampleT
# > Number of participants: 31
# > Mask : MNI_GM_3mm_SMC.nii
# > Saved here : /media/miplab-nas2/Data3/BMPD/hc_project//brain_spine/results/seed_to_voxels//2_second_level/OneSampleT/MNI_GM_3mm_SMC/MI/icap_C4
#
# **************************************
# Initiate icap_C5 analysis
#
# > Statistical model: OneSampleT
# > Number of participants: 31
# > Mask : MNI_GM_3mm_SMC.nii
# > Saved here : /media/miplab-nas2/Data3/BMPD/hc_project//brain_spine/results/seed_to_voxels//2_second_level/OneSampleT/MNI_GM_3mm_SMC/MI/icap_C5
#
# **************************************
# Initiate icap_C6 analysis
#
# > Statistical model: OneSampleT
# > Number of participants: 31
# > Mask : MNI_GM_3mm_SMC.nii
# > Saved here : /media/miplab-nas2/Data3/BMPD/hc_project//brain_spine/results/seed_to_voxels//2_second_level/OneSampleT/MNI_GM_3mm_SMC/MI/icap_C6
#
# **************************************
# Initiate icap_C7 analysis
#
# > Statistical model: OneSampleT
# > Number of participants: 31
# > Mask : MNI_GM_3mm_SMC.nii
# > Saved here : /media/miplab-nas2/Data3/BMPD/hc_project//brain_spine/results/seed_to_voxels//2_second_level/OneSampleT/MNI_GM_3mm_SMC/MI/icap_C7

# %% [markdown]
# ## <font color=#B2D732> <span style="background-color: #4424D6"> B/ SnPM

# %%
for ana_name in ana2run:
    stats[ana_name].snpm_OneSampleT(100,17,ana_name,ana_name + "_FWE05.nii")
# Out:
# SPM_Dir =
#
#     '/home/kinany/Code/iCAPs_latest/packages/spm12/'
#
#
# permutation =
#
#   int64
#
#    100
#
#
# matlabbatch =
#
#   1x1 cell array
#
#     {1x1 struct}
#
#
#
# ------------------------------------------------------------------------
# Running job #1
# ------------------------------------------------------------------------
# Running 'MultiSub: One Sample T test on diffs/contrasts'
# Warning: Very few (10) permutations used, nonparametric P-values are very coarse will vary
# substantially over repeated re-analyses.Smallest possible P-value is 0.1000.
# > In snpm_check_nperm (line 35)
# In snpm_pi_OneSampT (line 167)
# In snpm_ui (line 297)
# In snpm_run_ui (line 12)
# In cfg_run_cm (line 29)
# In cfg_util>local_runcj (line 1688)
# In cfg_util (line 959)
# In spm_jobman>fill_run_job (line 469)
# In spm_jobman (line 247)
# In SnPM_OneSampT_NK (line 52)
# Failed  'MultiSub: One Sample T test on diffs/contrasts'
# Brace indexing is not supported for variables of this type.
# In file "/home/kinany/Code/iCAPs_latest/packages/spm12/toolbox/snpm/snpm_ui.m" (???), function "snpm_ui" at line 440.
# In file "/home/kinany/Code/iCAPs_latest/packages/spm12/toolbox/snpm/config/snpm_run_ui.m" (???), function "snpm_run_ui" at line 12.
#
# No executable modules, but still unresolved dependencies or incomplete module inputs.
# The following modules did not run:
# Failed: MultiSub: One Sample T test on diffs/contrasts
# Skipped: Compute
# Skipped: Inference
# Error using MATLABbatch system
# Job execution failed. The full log of this run can be found in MATLAB command window, starting with the lines (look for the line showing the exact #job as displayed in this error message)
# ------------------
# Running job #1
# ------------------
# ---------------------------------------------------------------------------
# MatlabExecutionError                      Traceback (most recent call last)
# Cell In[42], line 2
#       1 for ana_name in ana2run:
# ----> 2     stats[ana_name].snpm_OneSampleT(100,17,ana_name,ana_name + "_FWE05.nii")
#
# File /media/miplab-nas2/Data3/BMPD/hc_project/analysis/code/stats_group_level_NK.py:360, in Stats.snpm_OneSampleT(self, permutation, t_thr, seed_name, output_filename)
#     357 if self.mask_img.split(".")[-1] == "gz":
#     358     raise ValueError(">>>> Mask image should be unzip for SnPM (.nii)")
# --> 360 print(eng.SnPM_OneSampT_NK(permutation,t_thr,os.path.dirname(self.data_1rstlevel[seed_name][0]),self.tag_file + "_"+ str(len(self.config['list_subjects'])) + "subjects" ,self.mask_img,output_snpm,output_filename))
#
# File ~/anaconda3/lib/python3.9/site-packages/matlab/engine/matlabengine.py:70, in MatlabFunc.__call__(self, *args, **kwargs)
#      68     return FutureResult(self._engine(), future, nargs, _stdout, _stderr, feval=True)
#      69 else:
# ---> 70     return FutureResult(self._engine(), future, nargs, _stdout,
#      71                         _stderr, feval=True).result()
#
# File ~/anaconda3/lib/python3.9/site-packages/matlab/engine/futureresult.py:67, in FutureResult.result(self, timeout)
#      64     if timeout < 0:
#      65         raise TypeError(pythonengine.getMessage('TimeoutCannotBeNegative'))
# ---> 67 return self.__future.result(timeout)
#
# File ~/anaconda3/lib/python3.9/site-packages/matlab/engine/fevalfuture.py:82, in FevalFuture.result(self, timeout)
#      79 if not result_ready:
#      80     raise TimeoutError(pythonengine.getMessage('MatlabFunctionTimeout'))
# ---> 82 self._result = pythonengine.getFEvalResult(self._future,self._nargout, None, out=self._out, err=self._err)
#      83 self._retrieved = True
#      84 return self._result
#
# MatlabExecutionError:
#   File , line 0, in MATLABbatch system
# Job execution failed. The full log of this run can be found in MATLAB command window, starting with the lines (look for the line showing the exact #job as displayed in this error message)
# ------------------
# Running job #1
# ------------------

# %% [markdown]
# ## <font color=#B2D732> <span style="background-color: #4424D6"> B/ Create design matrix

# %%
Design_matrix={}
for ana_name in ana2run:
    Design_matrix[ana_name]=stats[ana_name].design_matrix(plot_matrix= True,save_matrix=True) #contrast_name="4quad_9levels",

# %% [markdown]
# ## <font color=#B2D732> <span style="background-color: #4424D6"> C/ Create second level model and apply correction

# %%
maps_uncorr={}
for ana_name in ana2run:
    maps_uncorr[ana_name]=stats[ana_name].secondlevelmodel(Design_matrix[ana_name],plot_2ndlevel=False,save_img=True,parametric=True) #stats_1T.secondlevelmodel(Design_matrix_1T)
    stats[ana_name].secondlevel_correction(maps_uncorr[ana_name],p_value=0.05,cluster_threshold=20,corr='fpr',plot_stats_corr=True,save_img=True) #stats_1T.secondlevelmodel(Design_matrix_1T)

# %%
import numpy as np
np.hstack((np.tile(([[1] * 2+ [0] * 2]),2)))
# Out:
# array([1, 1, 0, 0, 1, 1, 0, 0])

# %% [markdown]
# ## <font color=#B2D732> <span style="background-color: #4424D6"> D/ plot surface view

# %%
from nilearn import plotting
main_dir=config["second_level"]+"/OneSampleT/MNI_GM_3mm/"
seeds=["C1C7_gmwm"]#,"C1C7_DL_gmwm","C1C7_VR_gmwm","C1C7_VL_gmwm"]
measures=["MI"]
for seed in seeds:

    for measure in measures:
        image=glob.glob(main_dir + "/" + measure + "/" + seed + "/uncorr/zscore*")[0]

        #image=glob.glob(main_dir + "/" + measure + "/" + seed + "/fpr_corrected/Main "+seed+"_fpr_p01.nii.gz")[0]



        #plotting.plot_stat_map(image,threshold=0, vmax=4, display_mode='ortho',draw_cross=False,cut_coords=[-1,-17.5,59],title=measure + " " + seed)

        plotting.plot_glass_brain(image,threshold=8.2, vmax=17, title=measure + " " + seed)

# %%
from nilearn import plotting
main_dir=config["second_level"]+"/TwoSampT_paired/MNI_GM_3mm_SMC/"
seeds=["C1C7_DR-DL_gmwm","C1C7_VR-VL_gmwm"]
measures=["Corr","MI"]
for seed in seeds:
    for measure in measures:
        image1=glob.glob(main_dir + "/" + measure + "/" + seed + "/fpr_corrected/"+ seed.split("-")[0] + "*fpr_p01.nii.gz")[0]
        image2=glob.glob(main_dir + "/" + measure + "/" + seed + "/fpr_corrected/C1C7_"+ seed.split("-")[-1] + "*fpr_p01.nii.gz")[0]

        plotting.plot_glass_brain(image1,threshold=0, vmax=4, title=measure + " " + seed)
        plotting.plot_glass_brain(image2,threshold=0, vmax=4, title=measure + " " + seed + " inverse")
# Out:
# /cerebro/cerebro1/dataset/bmpd/derivatives/thibault_test/code/toolbox/bmpd_python/lib/python3.6/site-packages/nilearn/plotting/displays/_slicers.py:382: UserWarning: empty mask
#   get_mask_bounds(new_img_like(img, not_mask, affine))

# %%
ana_name
# Out:
# 'C1C7_VL-DL_gmwm'

# %%
import matlab.engine
import stats_snpm
sys.path.append("/media/miplab-nas2/Data3/BMPD/hc_project/analysis/code/stats_snpm/")

os.chdir("/media/miplab-nas2/Data3/BMPD/hc_project/analysis/code/stats_snpm/")
eng = matlab.engine.start_matlab()
