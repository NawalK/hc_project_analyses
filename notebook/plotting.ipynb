# %%
import sys,json

sys.path.append("/cerebro/cerebro1/dataset/bmpd/derivatives/HealthyControls_project/hc_project_analyses/code/")

from plotting import Plotting
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Load configuration file

# %%
with open('../config/config_CL.json') as config_file:
    config = json.load(config_file)

# %%
plotting = Plotting(config,9,['iCAP']) # "'ICA'" or "iCAP" or ['ICA','iCAP']
# Out:
# ['iCAP']

# %%
plotting.sc_plot(show_spinal_levels=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-88-52e3f5e7586c> in <module>
# ----> 1 plotting.sc_plot(show_spinal_levels=True)
#
# /cerebro/cerebro1/dataset/bmpd/derivatives/HealthyControls_project/hc_project_analyses/code/plotting.py in sc_plot(self, k_per_line, lthresh, uthresh, centering_method, show_spinal_levels, colormap, save_results)
#     116                     else:
#     117                         alpha=0.6
# --> 118                     axs[row_coronal,col].imshow(np.rot90(map_masked[ana][:,max_y,:,i]),vmin=lthresh, vmax=uthresh,cmap=colormap[ana],alpha=alpha)
#     119
#     120             else:
#
# TypeError: string indices must be integers

# %%
a={'ICA':0,'iCAP':1}
len(a)
# Out:
# 2

# %%
sorted(glob.glob(self.config['templates']["sc_levels_path"] + 'spinal_level_*.nii.gz'))

# %%
#- ajouter boucle super position
