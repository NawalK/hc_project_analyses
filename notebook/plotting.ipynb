# %%
import sys,json

sys.path.append("/cerebro/cerebro1/dataset/bmpd/derivatives/HealthyControls_project/hc_project_analyses/code/")

from plotting import Plotting
from compute_similarity import compute_similarity

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Load configuration file

# %%
with open('../config/config_CL.json') as config_file:
    config = json.load(config_file)

# %%
import glob
import nibabel as nib
data1=nib.load(glob.glob(config['main_dir'] + "/ICA/spinalcord_20/Comp_zscored/"+ '*4D*.nii*')[0]).get_fdata()
data2=nib.load(glob.glob(config['main_dir'] + "/iCAP/spinalcord_20/Comp_zscored/"+ '*4D*.nii*')[0]).get_fdata()

# %%
plotting = Plotting(config,9,['ICA','iCAP']) # "'ICA'" or "iCAP" or ['ICA','iCAP']
# Out:
# ['ICA', 'iCAP']
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: int() argument must be a string, a bytes-like object or a number, not 'tuple'
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-9d94796f3e9f> in <module>
# ----> 1 plotting = Plotting(config,9,['ICA','iCAP']) # "'ICA'" or "iCAP" or ['ICA','iCAP']
#
# /cerebro/cerebro1/dataset/bmpd/derivatives/HealthyControls_project/hc_project_analyses/code/plotting.py in __init__(self, config, k, analyses, sorting_method)
#      36                 self.data[ana] = self.data[ana][:,:,:,self.map_order[ana]]
#      37
# ---> 38         self.spinal_levels = self._match_levels()
#      39
#      40     def sc_plot(self, k_per_line=None, lthresh=2.3, uthresh=4.0, centering_method='max', show_spinal_levels=False, colormap='autumn', save_results=False):
#
# /cerebro/cerebro1/dataset/bmpd/derivatives/HealthyControls_project/hc_project_analyses/code/plotting.py in _match_levels(self, method)
#     209             CoM = np.zeros(map_masked.shape[3],dtype='int')
#     210             for i in range(0,self.k):
# --> 211                 CoM[i]=center_of_mass(self.data[self.analyses[0]][:,:,:,i])
#     212                 print(CoM)
#     213                 # Take this point for each level (we focus on rostrocaudal position and take center of FOV for the other dimensions)
#
# ValueError: setting an array element with a sequence.

# %%
plotting.sc_plot(show_spinal_levels=True,k_per_line=10,save_results = True)
# Out:
# COMPUTING SIMILARITY WITH METHOD: Dice
# ...Compute similarity between pairs of components
# ...Ordering components based on maximum weight matching
# DONE!

# %%
if len(self.analyses)==2:
                    mask1=np.where(~np.isnan(self.data[self.analyses[0]]),self.data[self.analyses[1]], np.nan)
                    mask2=np.where(~np.isnan(self.data[self.analyses[1]]), self.data[self.analyses[0]], np.nan)
                    overlap_map=(mask1+mask2)/2 
                    max_y = int(np.where(overlap_map== np.nanmax(overlap_map[:,:,:,i]))[1])
                
                else:

# %%
a_maskb=np.where(~np.isnan(a), b, np.nan)
b_maska=np.where(~np.isnan(b), a, np.nan)
(a_maskb+b_maska)/2
#b_maska
# Out:
# array([5.5, 7. , nan, nan, 6. ])

# %%
a_maskb
# Out:
# array([ 1.,  2., nan, nan,  6.])

# %%
b[ True,  True,  True, False,  True]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-123-20d43bf4c329> in <module>
# ----> 1 b[ True,  True,  True, False,  True]
#
# TypeError: list indices must be integers or slices, not tuple

# %%
sorted(glob.glob(self.config['templates']["sc_levels_path"] + 'spinal_level_*.nii.gz'))

# %%
#- ajouter boucle super position
